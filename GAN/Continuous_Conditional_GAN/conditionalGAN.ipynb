# %%
import os
import numpy as np
import math
from torchvision import transforms, datasets
from torchvision.utils import save_image
from torch.utils.data import DataLoader

import torch.nn as nn
import torch.nn.functional as F
import torch
img_save_path = './conditionalGAN/images/'
os.makedirs(img_save_path, exist_ok=True)

n_epochs = 200 # number of epochs of training
batch_size = 64 # size of the batches
lr = 0.0002 # learning rate
beta1 = 0.5 # decay of the first order mmomentum of gradient
beta2 = 0.999 # decay of second order momentum of gradient
latent_dim = 100 # dim of the latent space
n_classes = 10 # number of classes for dataset
image_size = 28 # size of each image dimension
channels = 1 # number of image channels
sample_interval = 200 # interval between image sampling
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        torch.nn.init.normal(m.weight,0.0,0.02)
    elif classname.find('BatchNorm2d')!=-1:
        torch.nn.init.normal(m.weight,1.0,0.02)
        torch.nn.init.constant(m.bias,0.0)
        
def idx2onehot(idx, n):
    assert torch.max(idx).item() < n and idx.dim() == 1
    idx2dim = idx.view(-1,1) # change from 1-dim tensor to 2-dim tensor
    onehot = torch.zeros(idx2dim.size(0),n).scatter_(1,idx2dim,1)

    return onehot


    
class Generator(nn.Module):
    # initializers
    def __init__(self):
        super().__init__()
        self.fc1_1 = nn.Linear(latent_dim,256)
        self.fc1_1_bn = nn.BatchNorm1d(256)
        self.fc1_2 = nn.Linear(10, 256)
        self.fc1_2_bn = nn.BatchNorm1d(256)
        self.fc2 = nn.Linear(512,512)
        self.fc2_bn = nn.BatchNorm1d(512)
        self.fc3 = nn.Linear(512,1024)
        self.fc3_bn = nn.BatchNorm1d(1024)
        self.fc4 = nn.Linear(1024,image_size**2)
    
    # forward method
    def forward(self, z, y):
        x1 = F.relu(self.fc1_1_bn(self.fc1_1(z)))
        x2 = F.relu(self.fc1_2_bn(self.fc1_2(y)))
        x = torch.cat([x1, x2], dim = 1)
        x = F.relu(self.fc2_bn(self.fc2(x)))
        x = F.relu(self.fc3_bn(self.fc3(x)))
        x = torch.tanh(self.fc4(x))
        return x
    
class Discriminator(nn.Module):
    # initializers
    def __init__(self):
        super().__init__()
        self.fc1_1 = nn.Linear(image_size**2, 1024)
        self.fc1_2 = nn.Linear(10, 1024)
        self.fc2 = nn.Linear(2048, 512)
        self.fc2_bn = nn.BatchNorm1d(512)
        self.fc3 = nn.Linear(512,256)
        self.fc3_bn = nn.BatchNorm1d(256)
        self.fc4 = nn.Linear(256, 1)
        
        # forward method
    def forward(self, input, y):
        x1 = F.leaky_relu(self.fc1_1(input), 0.2)
        x2 = F.leaky_relu(self.fc1_2(y),0.2)
        x = torch.cat([x1, x2], dim = 1)
        x = F.leaky_relu(self.fc2_bn(self.fc2(x)),0.2)
        x = F.leaky_relu(self.fc3_bn(self.fc3(x)),0.2)
        x = torch.sigmoid(self.fc4(x))
        return x
        
# Loss function
loss = torch.nn.BCELoss()

# Initialize Generator and discriminator
generator = Generator()
discriminator = Discriminator()

# Move model to the corresponding device
generator.to(device)
discriminator.to(device)

# Initialize weights
#generator.apply(weights_init_normal)
#discriminator.apply(weights_init_normal)

data_save_path = './conditionalGAN/data/'
os.makedirs(data_save_path, exist_ok = True)
# 
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*channels,[0.5]*channels)
   
])
dataset = datasets.MNIST(root = data_save_path, train = True, download = True, transform=transform)


dataloader = DataLoader(dataset,batch_size = batch_size,shuffle=True,drop_last = True)
print("the data is OK")
# Out:
# the data is OK

# %%
# Optimizers
optimizer_G = torch.optim.Adam(generator.parameters(),lr = lr, betas = (beta1, beta2))
optimizer_D = torch.optim.Adam(discriminator.parameters(),lr = lr, betas = (beta1, beta2))
def reset_grad():
    optimizer_D.zero_grad()
    optimizer_G.zero_grad()

# %%
def sample_image(n_row, n_col,epoch):
    """Saves a grid of generated digits ranging from 0 to n_classes"""
    # Sample noise
    z = torch.randn(n_row*n_col, latent_dim).to(device)
    # Get labels ranging from 0 to n_classes for n rows
    labels = torch.Tensor([num for _ in range(n_col) for num in range(n_row)]).type(torch.LongTensor)
    labels = idx2onehot(labels,n_classes).to(device)
    gen_imgs = generator(z, labels).view(z.size(0),channels,image_size,image_size) # reshape the output of the generator
    save_image(gen_imgs.data, os.path.join(img_save_path,'{}.png'.format(epoch)),nrow=n_row, normalize=True)

# %%
total_step = len(dataloader)

for epoch in range(n_epochs):
    for i, (images, labels) in enumerate(dataloader):
        images = images.view(images.size(0), -1).to(device)
        
        real_labels = torch.ones(batch_size,1).to(device)
        fake_labels = torch.zeros(batch_size,1).to(device)
        
        # Configure labels
        
        labels_onehot = idx2onehot(labels,n_classes).to(device)

        
        # =============================================
        #
        #  Training Discriminator 
        #
        # =============================================
        
        outputs = discriminator(images,labels_onehot)
        d_loss_real = loss(outputs, real_labels)
        real_score = outputs # just for the purpose of tracking training progress
        
        z = torch.randn(batch_size, latent_dim).to(device)
        label_z = idx2onehot(torch.randint(n_classes,(batch_size,)),n_classes).to(device)
        
        fake_images = generator(z,label_z).detach()
        outputs = discriminator(fake_images,label_z)
        d_loss_fake = loss(outputs, fake_labels)
        fake_score = outputs # just for the purpose of tracking training progress
        
        # Backprop and optimize
        d_loss = d_loss_real + d_loss_fake
        reset_grad() # reset stored gradients
        d_loss.backward()
        optimizer_D.step()
        
        
        # =============================================
        #
        #  Training Generator
        #
        # ============================================
        
        z = torch.randn(batch_size, latent_dim).to(device)
        label_z = idx2onehot(torch.randint(n_classes,(batch_size,)),n_classes).to(device)

        fake_images = generator(z,label_z)
        outputs = discriminator(fake_images,label_z)
        g_loss = loss(outputs, real_labels)
        reset_grad()
        g_loss.backward()
        optimizer_G.step()
        
        if (i+1) % sample_interval == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss:{:.2f}, D(x):{:.2f}, D(G(z)): {:.2f}'.format(epoch, n_epochs, i+1, total_step, d_loss.item(), g_loss.item(), real_score.mean().item(), fake_score.mean().item()))
          
    sample_image(n_row=10,n_col=10,epoch=epoch)
# Out:
# Epoch [0/200], Step [200/937], d_loss: 1.1161, g_loss:0.94, D(x):0.57, D(G(z)): 0.42
# Epoch [0/200], Step [400/937], d_loss: 1.1329, g_loss:0.96, D(x):0.56, D(G(z)): 0.42
# Epoch [0/200], Step [600/937], d_loss: 1.1653, g_loss:0.91, D(x):0.57, D(G(z)): 0.44
# Epoch [0/200], Step [800/937], d_loss: 0.9513, g_loss:0.93, D(x):0.61, D(G(z)): 0.36
# Epoch [1/200], Step [200/937], d_loss: 1.0670, g_loss:0.92, D(x):0.57, D(G(z)): 0.38
# Epoch [1/200], Step [400/937], d_loss: 1.1945, g_loss:0.74, D(x):0.54, D(G(z)): 0.42
# Epoch [1/200], Step [600/937], d_loss: 1.0021, g_loss:0.98, D(x):0.63, D(G(z)): 0.40
# Epoch [1/200], Step [800/937], d_loss: 1.2912, g_loss:1.10, D(x):0.49, D(G(z)): 0.40
# Epoch [2/200], Step [200/937], d_loss: 1.3802, g_loss:0.97, D(x):0.52, D(G(z)): 0.49
# Epoch [2/200], Step [400/937], d_loss: 1.0948, g_loss:1.23, D(x):0.60, D(G(z)): 0.42
# Epoch [2/200], Step [600/937], d_loss: 1.2602, g_loss:0.82, D(x):0.53, D(G(z)): 0.45
# Epoch [2/200], Step [800/937], d_loss: 1.0631, g_loss:1.08, D(x):0.51, D(G(z)): 0.30
# Epoch [3/200], Step [200/937], d_loss: 1.1948, g_loss:1.30, D(x):0.51, D(G(z)): 0.36
# Epoch [3/200], Step [400/937], d_loss: 1.2031, g_loss:1.07, D(x):0.62, D(G(z)): 0.49
# Epoch [3/200], Step [600/937], d_loss: 1.0597, g_loss:0.92, D(x):0.66, D(G(z)): 0.45
# Epoch [3/200], Step [800/937], d_loss: 0.8859, g_loss:0.76, D(x):0.58, D(G(z)): 0.26
# Epoch [4/200], Step [200/937], d_loss: 0.8970, g_loss:1.18, D(x):0.63, D(G(z)): 0.33
# Epoch [4/200], Step [400/937], d_loss: 0.8012, g_loss:0.78, D(x):0.64, D(G(z)): 0.28
# Epoch [4/200], Step [600/937], d_loss: 0.7581, g_loss:1.33, D(x):0.71, D(G(z)): 0.31
# Epoch [4/200], Step [800/937], d_loss: 0.4188, g_loss:2.31, D(x):0.80, D(G(z)): 0.17
# Epoch [5/200], Step [200/937], d_loss: 0.2563, g_loss:2.66, D(x):0.89, D(G(z)): 0.12
# Epoch [5/200], Step [400/937], d_loss: 0.9988, g_loss:1.69, D(x):0.50, D(G(z)): 0.21
# Epoch [5/200], Step [600/937], d_loss: 0.9601, g_loss:1.89, D(x):0.69, D(G(z)): 0.40
# Epoch [5/200], Step [800/937], d_loss: 0.9211, g_loss:1.07, D(x):0.59, D(G(z)): 0.27
# Epoch [6/200], Step [200/937], d_loss: 0.9260, g_loss:1.37, D(x):0.69, D(G(z)): 0.40
# Epoch [6/200], Step [400/937], d_loss: 1.3378, g_loss:1.12, D(x):0.63, D(G(z)): 0.54
# Epoch [6/200], Step [600/937], d_loss: 0.9535, g_loss:1.49, D(x):0.55, D(G(z)): 0.27
# Epoch [6/200], Step [800/937], d_loss: 1.0366, g_loss:1.71, D(x):0.67, D(G(z)): 0.44
# Epoch [7/200], Step [200/937], d_loss: 1.0093, g_loss:1.20, D(x):0.51, D(G(z)): 0.23
# Epoch [7/200], Step [400/937], d_loss: 0.7450, g_loss:1.15, D(x):0.72, D(G(z)): 0.32
# Epoch [7/200], Step [600/937], d_loss: 0.8027, g_loss:0.85, D(x):0.62, D(G(z)): 0.25
# Epoch [7/200], Step [800/937], d_loss: 0.8037, g_loss:1.33, D(x):0.78, D(G(z)): 0.40
# Epoch [8/200], Step [200/937], d_loss: 0.8803, g_loss:1.23, D(x):0.66, D(G(z)): 0.34
# Epoch [8/200], Step [400/937], d_loss: 0.9589, g_loss:1.32, D(x):0.54, D(G(z)): 0.24
# Epoch [8/200], Step [600/937], d_loss: 0.3334, g_loss:2.13, D(x):0.90, D(G(z)): 0.20
# Epoch [8/200], Step [800/937], d_loss: 0.3517, g_loss:3.10, D(x):0.81, D(G(z)): 0.12
# Epoch [9/200], Step [200/937], d_loss: 1.0406, g_loss:1.86, D(x):0.85, D(G(z)): 0.54
# Epoch [9/200], Step [400/937], d_loss: 1.0002, g_loss:0.93, D(x):0.46, D(G(z)): 0.13
# Epoch [9/200], Step [600/937], d_loss: 0.8801, g_loss:1.62, D(x):0.54, D(G(z)): 0.17
# Epoch [9/200], Step [800/937], d_loss: 1.2379, g_loss:1.38, D(x):0.53, D(G(z)): 0.40
# Epoch [10/200], Step [200/937], d_loss: 1.1919, g_loss:1.13, D(x):0.39, D(G(z)): 0.16
# Epoch [10/200], Step [400/937], d_loss: 1.0689, g_loss:1.56, D(x):0.64, D(G(z)): 0.43
# Epoch [10/200], Step [600/937], d_loss: 1.2951, g_loss:1.34, D(x):0.59, D(G(z)): 0.50
# Epoch [10/200], Step [800/937], d_loss: 0.9925, g_loss:1.16, D(x):0.66, D(G(z)): 0.41
# Epoch [11/200], Step [200/937], d_loss: 0.7654, g_loss:0.97, D(x):0.69, D(G(z)): 0.29
# Epoch [11/200], Step [400/937], d_loss: 0.8276, g_loss:1.18, D(x):0.68, D(G(z)): 0.32
# Epoch [11/200], Step [600/937], d_loss: 1.1743, g_loss:0.79, D(x):0.50, D(G(z)): 0.34
# Epoch [11/200], Step [800/937], d_loss: 1.0071, g_loss:1.73, D(x):0.75, D(G(z)): 0.48
# Epoch [12/200], Step [200/937], d_loss: 0.8391, g_loss:1.35, D(x):0.69, D(G(z)): 0.34
# Epoch [12/200], Step [400/937], d_loss: 1.1044, g_loss:1.47, D(x):0.54, D(G(z)): 0.35
# Epoch [12/200], Step [600/937], d_loss: 1.0192, g_loss:0.68, D(x):0.67, D(G(z)): 0.42
# Epoch [12/200], Step [800/937], d_loss: 1.3440, g_loss:1.37, D(x):0.83, D(G(z)): 0.66
# Epoch [13/200], Step [200/937], d_loss: 1.2042, g_loss:1.05, D(x):0.46, D(G(z)): 0.29
# Epoch [13/200], Step [400/937], d_loss: 1.1798, g_loss:2.19, D(x):0.62, D(G(z)): 0.46
# Epoch [13/200], Step [600/937], d_loss: 1.3294, g_loss:1.63, D(x):0.47, D(G(z)): 0.39
# Epoch [13/200], Step [800/937], d_loss: 0.8148, g_loss:1.24, D(x):0.70, D(G(z)): 0.34
# Epoch [14/200], Step [200/937], d_loss: 0.7182, g_loss:1.40, D(x):0.72, D(G(z)): 0.30
# Epoch [14/200], Step [400/937], d_loss: 1.2968, g_loss:1.40, D(x):0.54, D(G(z)): 0.45
# Epoch [14/200], Step [600/937], d_loss: 0.8173, g_loss:1.38, D(x):0.60, D(G(z)): 0.23
# Epoch [14/200], Step [800/937], d_loss: 1.4154, g_loss:1.38, D(x):0.57, D(G(z)): 0.54
# Epoch [15/200], Step [200/937], d_loss: 1.2089, g_loss:0.75, D(x):0.61, D(G(z)): 0.47
# Epoch [15/200], Step [400/937], d_loss: 0.9509, g_loss:1.43, D(x):0.68, D(G(z)): 0.40
# Epoch [15/200], Step [600/937], d_loss: 0.9407, g_loss:1.46, D(x):0.66, D(G(z)): 0.37
# Epoch [15/200], Step [800/937], d_loss: 1.5346, g_loss:1.80, D(x):0.50, D(G(z)): 0.52
# Epoch [16/200], Step [200/937], d_loss: 1.1859, g_loss:1.26, D(x):0.55, D(G(z)): 0.39
# Epoch [16/200], Step [400/937], d_loss: 0.7495, g_loss:1.35, D(x):0.78, D(G(z)): 0.36
# Epoch [16/200], Step [600/937], d_loss: 0.8987, g_loss:1.60, D(x):0.74, D(G(z)): 0.42
# Epoch [16/200], Step [800/937], d_loss: 1.0354, g_loss:0.86, D(x):0.75, D(G(z)): 0.48
# Epoch [17/200], Step [200/937], d_loss: 1.2346, g_loss:1.85, D(x):0.84, D(G(z)): 0.62
# Epoch [17/200], Step [400/937], d_loss: 0.6213, g_loss:0.55, D(x):0.72, D(G(z)): 0.23
# Epoch [17/200], Step [600/937], d_loss: 1.6107, g_loss:1.50, D(x):0.57, D(G(z)): 0.58
# Epoch [17/200], Step [800/937], d_loss: 0.3348, g_loss:1.36, D(x):0.89, D(G(z)): 0.16
# Epoch [18/200], Step [200/937], d_loss: 1.3551, g_loss:1.42, D(x):0.32, D(G(z)): 0.10
# Epoch [18/200], Step [400/937], d_loss: 0.9035, g_loss:2.56, D(x):0.52, D(G(z)): 0.17
# Epoch [18/200], Step [600/937], d_loss: 0.6036, g_loss:1.64, D(x):0.80, D(G(z)): 0.29
# Epoch [18/200], Step [800/937], d_loss: 1.1923, g_loss:1.64, D(x):0.54, D(G(z)): 0.37
# Epoch [19/200], Step [200/937], d_loss: 0.7467, g_loss:2.13, D(x):0.72, D(G(z)): 0.31
# Epoch [19/200], Step [400/937], d_loss: 0.7227, g_loss:1.73, D(x):0.82, D(G(z)): 0.38
# Epoch [19/200], Step [600/937], d_loss: 0.2215, g_loss:1.40, D(x):0.96, D(G(z)): 0.16
# Epoch [19/200], Step [800/937], d_loss: 0.4333, g_loss:2.53, D(x):0.75, D(G(z)): 0.09
# Epoch [20/200], Step [200/937], d_loss: 0.5018, g_loss:1.80, D(x):0.96, D(G(z)): 0.33
# Epoch [20/200], Step [400/937], d_loss: 0.8101, g_loss:1.53, D(x):0.69, D(G(z)): 0.31
# Epoch [20/200], Step [600/937], d_loss: 0.3695, g_loss:1.31, D(x):0.95, D(G(z)): 0.26
# Epoch [20/200], Step [800/937], d_loss: 0.7413, g_loss:1.18, D(x):0.63, D(G(z)): 0.20
# Epoch [21/200], Step [200/937], d_loss: 0.7288, g_loss:1.37, D(x):0.57, D(G(z)): 0.10
# Epoch [21/200], Step [400/937], d_loss: 0.1417, g_loss:2.62, D(x):0.97, D(G(z)): 0.10
# Epoch [21/200], Step [600/937], d_loss: 0.1366, g_loss:3.46, D(x):0.94, D(G(z)): 0.06
# Epoch [21/200], Step [800/937], d_loss: 0.2118, g_loss:3.51, D(x):0.87, D(G(z)): 0.06
# Epoch [22/200], Step [200/937], d_loss: 0.3067, g_loss:2.60, D(x):0.91, D(G(z)): 0.18
# Epoch [22/200], Step [400/937], d_loss: 0.3982, g_loss:3.14, D(x):0.84, D(G(z)): 0.18
# Epoch [22/200], Step [600/937], d_loss: 0.8175, g_loss:3.07, D(x):0.94, D(G(z)): 0.50
# Epoch [22/200], Step [800/937], d_loss: 0.5070, g_loss:2.37, D(x):0.83, D(G(z)): 0.25
# Epoch [23/200], Step [200/937], d_loss: 0.4627, g_loss:2.98, D(x):0.74, D(G(z)): 0.13
# Epoch [23/200], Step [400/937], d_loss: 0.4113, g_loss:1.05, D(x):0.76, D(G(z)): 0.09
# Epoch [23/200], Step [600/937], d_loss: 0.7716, g_loss:1.76, D(x):0.65, D(G(z)): 0.24
# Epoch [23/200], Step [800/937], d_loss: 0.5782, g_loss:2.40, D(x):0.92, D(G(z)): 0.35
# Epoch [24/200], Step [200/937], d_loss: 0.6601, g_loss:2.08, D(x):0.79, D(G(z)): 0.32
# Epoch [24/200], Step [400/937], d_loss: 0.2969, g_loss:1.69, D(x):0.93, D(G(z)): 0.19
# Epoch [24/200], Step [600/937], d_loss: 0.9531, g_loss:1.61, D(x):0.77, D(G(z)): 0.45
# Epoch [24/200], Step [800/937], d_loss: 0.4717, g_loss:1.74, D(x):0.71, D(G(z)): 0.07
# Epoch [25/200], Step [200/937], d_loss: 0.6275, g_loss:3.00, D(x):0.90, D(G(z)): 0.35
# Epoch [25/200], Step [400/937], d_loss: 0.3126, g_loss:2.68, D(x):0.81, D(G(z)): 0.09
# Epoch [25/200], Step [600/937], d_loss: 0.4172, g_loss:2.50, D(x):0.98, D(G(z)): 0.31
# Epoch [25/200], Step [800/937], d_loss: 0.4015, g_loss:2.08, D(x):0.79, D(G(z)): 0.14
# Epoch [26/200], Step [200/937], d_loss: 0.6422, g_loss:2.63, D(x):0.71, D(G(z)): 0.19
# Epoch [26/200], Step [400/937], d_loss: 1.0365, g_loss:2.76, D(x):0.45, D(G(z)): 0.09
# Epoch [26/200], Step [600/937], d_loss: 0.1716, g_loss:3.01, D(x):0.90, D(G(z)): 0.06
# Epoch [26/200], Step [800/937], d_loss: 0.4209, g_loss:2.43, D(x):0.85, D(G(z)): 0.19
# Epoch [27/200], Step [200/937], d_loss: 0.3372, g_loss:3.05, D(x):0.87, D(G(z)): 0.17
# Epoch [27/200], Step [400/937], d_loss: 0.2443, g_loss:3.72, D(x):0.88, D(G(z)): 0.10
# Epoch [27/200], Step [600/937], d_loss: 0.1517, g_loss:3.13, D(x):0.98, D(G(z)): 0.12
# Epoch [27/200], Step [800/937], d_loss: 0.7392, g_loss:2.62, D(x):0.67, D(G(z)): 0.15
# Epoch [28/200], Step [200/937], d_loss: 0.4503, g_loss:2.85, D(x):0.93, D(G(z)): 0.30
# Epoch [28/200], Step [400/937], d_loss: 0.2857, g_loss:1.82, D(x):0.91, D(G(z)): 0.16
# Epoch [28/200], Step [600/937], d_loss: 0.3308, g_loss:1.81, D(x):0.96, D(G(z)): 0.23
# Epoch [28/200], Step [800/937], d_loss: 0.1807, g_loss:2.01, D(x):0.97, D(G(z)): 0.13
# Epoch [29/200], Step [200/937], d_loss: 0.4231, g_loss:3.26, D(x):0.80, D(G(z)): 0.14
# Epoch [29/200], Step [400/937], d_loss: 0.3205, g_loss:3.75, D(x):0.78, D(G(z)): 0.05
# Epoch [29/200], Step [600/937], d_loss: 0.2816, g_loss:2.79, D(x):0.97, D(G(z)): 0.20
# Epoch [29/200], Step [800/937], d_loss: 0.3585, g_loss:3.24, D(x):0.95, D(G(z)): 0.24
# Epoch [30/200], Step [200/937], d_loss: 0.1153, g_loss:1.64, D(x):0.97, D(G(z)): 0.08
# Epoch [30/200], Step [400/937], d_loss: 0.3235, g_loss:2.82, D(x):0.86, D(G(z)): 0.14
# Epoch [30/200], Step [600/937], d_loss: 0.2686, g_loss:3.66, D(x):0.95, D(G(z)): 0.18
# Epoch [30/200], Step [800/937], d_loss: 0.2167, g_loss:2.49, D(x):0.96, D(G(z)): 0.15
# Epoch [31/200], Step [200/937], d_loss: 0.2377, g_loss:3.20, D(x):0.85, D(G(z)): 0.06
# Epoch [31/200], Step [400/937], d_loss: 0.5625, g_loss:1.84, D(x):0.96, D(G(z)): 0.37
# Epoch [31/200], Step [600/937], d_loss: 0.2460, g_loss:3.16, D(x):0.83, D(G(z)): 0.04
# Epoch [31/200], Step [800/937], d_loss: 0.2496, g_loss:1.96, D(x):0.92, D(G(z)): 0.14
# Epoch [32/200], Step [200/937], d_loss: 0.3310, g_loss:2.98, D(x):0.77, D(G(z)): 0.04
# Epoch [32/200], Step [400/937], d_loss: 0.1789, g_loss:2.01, D(x):0.95, D(G(z)): 0.11
# Epoch [32/200], Step [600/937], d_loss: 0.5241, g_loss:1.15, D(x):0.70, D(G(z)): 0.08
# Epoch [32/200], Step [800/937], d_loss: 0.2308, g_loss:3.95, D(x):0.88, D(G(z)): 0.07
# Epoch [33/200], Step [200/937], d_loss: 0.2007, g_loss:3.73, D(x):1.00, D(G(z)): 0.17
# Epoch [33/200], Step [400/937], d_loss: 0.8243, g_loss:3.58, D(x):0.95, D(G(z)): 0.44
# Epoch [33/200], Step [600/937], d_loss: 0.0351, g_loss:3.27, D(x):0.99, D(G(z)): 0.03
# Epoch [33/200], Step [800/937], d_loss: 0.4361, g_loss:1.77, D(x):0.92, D(G(z)): 0.19
# Epoch [34/200], Step [200/937], d_loss: 0.1331, g_loss:1.98, D(x):0.93, D(G(z)): 0.06
# Epoch [34/200], Step [400/937], d_loss: 0.2391, g_loss:3.05, D(x):0.90, D(G(z)): 0.12
# Epoch [34/200], Step [600/937], d_loss: 0.0791, g_loss:4.56, D(x):0.95, D(G(z)): 0.03
# Epoch [34/200], Step [800/937], d_loss: 0.2102, g_loss:2.83, D(x):0.87, D(G(z)): 0.05
# Epoch [35/200], Step [200/937], d_loss: 0.1830, g_loss:2.88, D(x):0.87, D(G(z)): 0.04
# Epoch [35/200], Step [400/937], d_loss: 0.1713, g_loss:3.36, D(x):0.90, D(G(z)): 0.06
# Epoch [35/200], Step [600/937], d_loss: 0.9565, g_loss:2.65, D(x):0.48, D(G(z)): 0.05
# Epoch [35/200], Step [800/937], d_loss: 0.1566, g_loss:2.77, D(x):0.91, D(G(z)): 0.05
# Epoch [36/200], Step [200/937], d_loss: 0.2657, g_loss:4.33, D(x):0.95, D(G(z)): 0.18
# Epoch [36/200], Step [400/937], d_loss: 0.1929, g_loss:1.71, D(x):0.94, D(G(z)): 0.11
# Epoch [36/200], Step [600/937], d_loss: 0.1954, g_loss:3.31, D(x):0.93, D(G(z)): 0.08
# Epoch [36/200], Step [800/937], d_loss: 0.3380, g_loss:3.89, D(x):0.80, D(G(z)): 0.05
# Epoch [37/200], Step [200/937], d_loss: 0.2135, g_loss:3.21, D(x):0.85, D(G(z)): 0.04
# Epoch [37/200], Step [400/937], d_loss: 0.2690, g_loss:4.16, D(x):0.80, D(G(z)): 0.02
# Epoch [37/200], Step [600/937], d_loss: 0.9370, g_loss:2.17, D(x):0.85, D(G(z)): 0.45
# Epoch [37/200], Step [800/937], d_loss: 0.1284, g_loss:1.12, D(x):0.99, D(G(z)): 0.10
# Epoch [38/200], Step [200/937], d_loss: 0.1051, g_loss:2.18, D(x):0.96, D(G(z)): 0.06
# Epoch [38/200], Step [400/937], d_loss: 0.1682, g_loss:3.96, D(x):0.90, D(G(z)): 0.06
# Epoch [38/200], Step [600/937], d_loss: 0.3525, g_loss:1.73, D(x):0.94, D(G(z)): 0.22
# Epoch [38/200], Step [800/937], d_loss: 0.5198, g_loss:3.19, D(x):0.65, D(G(z)): 0.03
# Epoch [39/200], Step [200/937], d_loss: 0.2957, g_loss:1.88, D(x):0.85, D(G(z)): 0.11
# Epoch [39/200], Step [400/937], d_loss: 0.0960, g_loss:3.93, D(x):0.93, D(G(z)): 0.03
# Epoch [39/200], Step [600/937], d_loss: 0.0242, g_loss:4.69, D(x):0.99, D(G(z)): 0.02
# Epoch [39/200], Step [800/937], d_loss: 0.2460, g_loss:4.08, D(x):0.90, D(G(z)): 0.11
# Epoch [40/200], Step [200/937], d_loss: 0.0512, g_loss:3.76, D(x):0.97, D(G(z)): 0.02
# Epoch [40/200], Step [400/937], d_loss: 0.5281, g_loss:2.92, D(x):0.66, D(G(z)): 0.02
# Epoch [40/200], Step [600/937], d_loss: 0.2503, g_loss:2.68, D(x):0.97, D(G(z)): 0.18
# Epoch [40/200], Step [800/937], d_loss: 0.5199, g_loss:2.03, D(x):0.69, D(G(z)): 0.04
# Epoch [41/200], Step [200/937], d_loss: 0.6935, g_loss:1.77, D(x):0.57, D(G(z)): 0.04
# Epoch [41/200], Step [400/937], d_loss: 0.0444, g_loss:4.94, D(x):1.00, D(G(z)): 0.04
# Epoch [41/200], Step [600/937], d_loss: 0.1226, g_loss:2.62, D(x):0.94, D(G(z)): 0.05
# Epoch [41/200], Step [800/937], d_loss: 0.1481, g_loss:4.50, D(x):1.00, D(G(z)): 0.12
# Epoch [42/200], Step [200/937], d_loss: 1.0740, g_loss:0.61, D(x):0.43, D(G(z)): 0.07
# Epoch [42/200], Step [400/937], d_loss: 0.1785, g_loss:3.22, D(x):0.97, D(G(z)): 0.13
# Epoch [42/200], Step [600/937], d_loss: 0.2049, g_loss:3.13, D(x):1.00, D(G(z)): 0.16
# Epoch [42/200], Step [800/937], d_loss: 0.7174, g_loss:3.67, D(x):0.62, D(G(z)): 0.06
# Epoch [43/200], Step [200/937], d_loss: 0.2486, g_loss:2.46, D(x):0.90, D(G(z)): 0.12
# Epoch [43/200], Step [400/937], d_loss: 0.0917, g_loss:3.54, D(x):1.00, D(G(z)): 0.08
# Epoch [43/200], Step [600/937], d_loss: 0.5030, g_loss:2.69, D(x):0.97, D(G(z)): 0.32
# Epoch [43/200], Step [800/937], d_loss: 0.4052, g_loss:3.60, D(x):0.72, D(G(z)): 0.01
# Epoch [44/200], Step [200/937], d_loss: 0.4949, g_loss:3.09, D(x):1.00, D(G(z)): 0.34
# Epoch [44/200], Step [400/937], d_loss: 0.8876, g_loss:1.20, D(x):0.68, D(G(z)): 0.31
# Epoch [44/200], Step [600/937], d_loss: 0.0876, g_loss:1.50, D(x):0.94, D(G(z)): 0.03
# Epoch [44/200], Step [800/937], d_loss: 0.2978, g_loss:2.72, D(x):0.91, D(G(z)): 0.15
# Epoch [45/200], Step [200/937], d_loss: 0.1791, g_loss:1.57, D(x):0.87, D(G(z)): 0.02
# Epoch [45/200], Step [400/937], d_loss: 0.1567, g_loss:4.65, D(x):1.00, D(G(z)): 0.13
# Epoch [45/200], Step [600/937], d_loss: 0.2250, g_loss:2.04, D(x):0.97, D(G(z)): 0.16
# Epoch [45/200], Step [800/937], d_loss: 0.1006, g_loss:2.53, D(x):0.96, D(G(z)): 0.06
# Epoch [46/200], Step [200/937], d_loss: 0.1102, g_loss:4.27, D(x):0.97, D(G(z)): 0.07
# Epoch [46/200], Step [400/937], d_loss: 0.1682, g_loss:4.09, D(x):0.91, D(G(z)): 0.06
# Epoch [46/200], Step [600/937], d_loss: 0.1803, g_loss:4.53, D(x):0.97, D(G(z)): 0.13
# Epoch [46/200], Step [800/937], d_loss: 0.0597, g_loss:3.14, D(x):0.99, D(G(z)): 0.05
# Epoch [47/200], Step [200/937], d_loss: 0.1399, g_loss:3.14, D(x):0.91, D(G(z)): 0.04
# Epoch [47/200], Step [400/937], d_loss: 0.2798, g_loss:2.98, D(x):0.98, D(G(z)): 0.21
# Epoch [47/200], Step [600/937], d_loss: 0.2488, g_loss:1.87, D(x):0.87, D(G(z)): 0.08
# Epoch [47/200], Step [800/937], d_loss: 0.0979, g_loss:2.30, D(x):0.95, D(G(z)): 0.04
# Epoch [48/200], Step [200/937], d_loss: 0.6749, g_loss:1.51, D(x):0.60, D(G(z)): 0.05
# Epoch [48/200], Step [400/937], d_loss: 0.1546, g_loss:3.59, D(x):0.95, D(G(z)): 0.08
# Epoch [48/200], Step [600/937], d_loss: 0.4066, g_loss:0.75, D(x):0.71, D(G(z)): 0.03
# Epoch [48/200], Step [800/937], d_loss: 0.3501, g_loss:2.79, D(x):0.75, D(G(z)): 0.03
# Epoch [49/200], Step [200/937], d_loss: 0.1499, g_loss:3.64, D(x):0.93, D(G(z)): 0.07
# Epoch [49/200], Step [400/937], d_loss: 0.1279, g_loss:0.98, D(x):0.96, D(G(z)): 0.08
# Epoch [49/200], Step [600/937], d_loss: 0.1978, g_loss:3.25, D(x):1.00, D(G(z)): 0.14
# Epoch [49/200], Step [800/937], d_loss: 0.3990, g_loss:3.82, D(x):0.79, D(G(z)): 0.12
# Epoch [50/200], Step [200/937], d_loss: 0.0388, g_loss:3.59, D(x):0.98, D(G(z)): 0.02
# Epoch [50/200], Step [400/937], d_loss: 0.0726, g_loss:3.89, D(x):0.95, D(G(z)): 0.02
# Epoch [50/200], Step [600/937], d_loss: 0.4622, g_loss:1.70, D(x):0.73, D(G(z)): 0.08
# Epoch [50/200], Step [800/937], d_loss: 0.3503, g_loss:4.04, D(x):0.92, D(G(z)): 0.21
# Epoch [51/200], Step [200/937], d_loss: 0.0396, g_loss:2.31, D(x):0.99, D(G(z)): 0.03
# Epoch [51/200], Step [400/937], d_loss: 0.7863, g_loss:2.38, D(x):0.96, D(G(z)): 0.46
# Epoch [51/200], Step [600/937], d_loss: 0.3816, g_loss:2.89, D(x):0.98, D(G(z)): 0.25
# Epoch [51/200], Step [800/937], d_loss: 0.1167, g_loss:5.29, D(x):0.94, D(G(z)): 0.04
# Epoch [52/200], Step [200/937], d_loss: 0.3112, g_loss:3.79, D(x):0.79, D(G(z)): 0.03
# Epoch [52/200], Step [400/937], d_loss: 0.1994, g_loss:4.58, D(x):1.00, D(G(z)): 0.17
# Epoch [52/200], Step [600/937], d_loss: 0.1273, g_loss:3.98, D(x):0.89, D(G(z)): 0.01
# Epoch [52/200], Step [800/937], d_loss: 0.2059, g_loss:4.07, D(x):0.99, D(G(z)): 0.17
# Epoch [53/200], Step [200/937], d_loss: 0.1912, g_loss:3.79, D(x):0.97, D(G(z)): 0.14
# Epoch [53/200], Step [400/937], d_loss: 0.0999, g_loss:5.61, D(x):0.93, D(G(z)): 0.02
# Epoch [53/200], Step [600/937], d_loss: 0.0791, g_loss:4.98, D(x):0.95, D(G(z)): 0.03
# Epoch [53/200], Step [800/937], d_loss: 0.3437, g_loss:2.56, D(x):0.79, D(G(z)): 0.08
# Epoch [54/200], Step [200/937], d_loss: 0.2179, g_loss:2.57, D(x):0.85, D(G(z)): 0.04
# Epoch [54/200], Step [400/937], d_loss: 0.2635, g_loss:5.03, D(x):1.00, D(G(z)): 0.22
# Epoch [54/200], Step [600/937], d_loss: 0.3430, g_loss:3.82, D(x):0.85, D(G(z)): 0.11
# Epoch [54/200], Step [800/937], d_loss: 0.5163, g_loss:2.09, D(x):1.00, D(G(z)): 0.36
# Epoch [55/200], Step [200/937], d_loss: 0.8851, g_loss:3.61, D(x):0.82, D(G(z)): 0.36
# Epoch [55/200], Step [400/937], d_loss: 0.2961, g_loss:4.17, D(x):0.79, D(G(z)): 0.03
# Epoch [55/200], Step [600/937], d_loss: 0.1180, g_loss:2.09, D(x):0.98, D(G(z)): 0.09
# Epoch [55/200], Step [800/937], d_loss: 0.2871, g_loss:4.67, D(x):0.88, D(G(z)): 0.13
# Epoch [56/200], Step [200/937], d_loss: 0.0774, g_loss:3.42, D(x):0.98, D(G(z)): 0.06
# Epoch [56/200], Step [400/937], d_loss: 0.1417, g_loss:3.48, D(x):0.94, D(G(z)): 0.07
# Epoch [56/200], Step [600/937], d_loss: 1.0029, g_loss:3.84, D(x):0.46, D(G(z)): 0.02
# Epoch [56/200], Step [800/937], d_loss: 0.2184, g_loss:2.81, D(x):0.97, D(G(z)): 0.16
# Epoch [57/200], Step [200/937], d_loss: 0.0500, g_loss:5.68, D(x):0.99, D(G(z)): 0.04
# Epoch [57/200], Step [400/937], d_loss: 0.1826, g_loss:2.58, D(x):0.92, D(G(z)): 0.09
# Epoch [57/200], Step [600/937], d_loss: 0.4578, g_loss:3.47, D(x):0.72, D(G(z)): 0.03
# Epoch [57/200], Step [800/937], d_loss: 0.7959, g_loss:4.50, D(x):0.92, D(G(z)): 0.40
# Epoch [58/200], Step [200/937], d_loss: 0.2175, g_loss:2.98, D(x):0.90, D(G(z)): 0.10
# Epoch [58/200], Step [400/937], d_loss: 0.0673, g_loss:4.31, D(x):0.96, D(G(z)): 0.03
# Epoch [58/200], Step [600/937], d_loss: 0.5391, g_loss:2.89, D(x):0.64, D(G(z)): 0.04
# Epoch [58/200], Step [800/937], d_loss: 0.0511, g_loss:4.24, D(x):1.00, D(G(z)): 0.05
# Epoch [59/200], Step [200/937], d_loss: 0.2878, g_loss:5.05, D(x):0.89, D(G(z)): 0.11
# Epoch [59/200], Step [400/937], d_loss: 0.2476, g_loss:3.00, D(x):0.97, D(G(z)): 0.17
# Epoch [59/200], Step [600/937], d_loss: 0.1996, g_loss:4.40, D(x):0.87, D(G(z)): 0.04
# Epoch [59/200], Step [800/937], d_loss: 0.6084, g_loss:2.91, D(x):0.66, D(G(z)): 0.11
# Epoch [60/200], Step [200/937], d_loss: 0.4037, g_loss:1.17, D(x):0.74, D(G(z)): 0.04
# Epoch [60/200], Step [400/937], d_loss: 0.3209, g_loss:3.14, D(x):1.00, D(G(z)): 0.25
# Epoch [60/200], Step [600/937], d_loss: 0.5881, g_loss:3.60, D(x):0.99, D(G(z)): 0.39
# Epoch [60/200], Step [800/937], d_loss: 0.3937, g_loss:3.11, D(x):0.99, D(G(z)): 0.26
# Epoch [61/200], Step [200/937], d_loss: 1.1643, g_loss:6.38, D(x):0.95, D(G(z)): 0.60
# Epoch [61/200], Step [400/937], d_loss: 0.0629, g_loss:4.81, D(x):1.00, D(G(z)): 0.06
# Epoch [61/200], Step [600/937], d_loss: 0.3198, g_loss:3.99, D(x):0.77, D(G(z)): 0.01
# Epoch [61/200], Step [800/937], d_loss: 0.3395, g_loss:3.66, D(x):0.95, D(G(z)): 0.23
# Epoch [62/200], Step [200/937], d_loss: 0.1444, g_loss:2.96, D(x):0.89, D(G(z)): 0.02
# Epoch [62/200], Step [400/937], d_loss: 0.1409, g_loss:4.19, D(x):0.96, D(G(z)): 0.09
# Epoch [62/200], Step [600/937], d_loss: 0.2384, g_loss:3.16, D(x):0.93, D(G(z)): 0.13
# Epoch [62/200], Step [800/937], d_loss: 0.2180, g_loss:1.84, D(x):0.94, D(G(z)): 0.12
# Epoch [63/200], Step [200/937], d_loss: 0.1224, g_loss:2.79, D(x):0.94, D(G(z)): 0.05
# Epoch [63/200], Step [400/937], d_loss: 0.2405, g_loss:5.41, D(x):0.83, D(G(z)): 0.03
# Epoch [63/200], Step [600/937], d_loss: 0.1786, g_loss:1.01, D(x):0.91, D(G(z)): 0.07
# Epoch [63/200], Step [800/937], d_loss: 0.1334, g_loss:4.84, D(x):0.94, D(G(z)): 0.06
# Epoch [64/200], Step [200/937], d_loss: 0.0735, g_loss:4.06, D(x):0.95, D(G(z)): 0.02
# Epoch [64/200], Step [400/937], d_loss: 0.0606, g_loss:4.82, D(x):1.00, D(G(z)): 0.05
# Epoch [64/200], Step [600/937], d_loss: 0.1217, g_loss:2.74, D(x):0.94, D(G(z)): 0.06
# Epoch [64/200], Step [800/937], d_loss: 0.2392, g_loss:3.12, D(x):0.88, D(G(z)): 0.09
# Epoch [65/200], Step [200/937], d_loss: 0.7988, g_loss:3.19, D(x):0.53, D(G(z)): 0.01
# Epoch [65/200], Step [400/937], d_loss: 0.2725, g_loss:3.94, D(x):0.92, D(G(z)): 0.11
# Epoch [65/200], Step [600/937], d_loss: 0.1788, g_loss:2.35, D(x):0.95, D(G(z)): 0.11
# Epoch [65/200], Step [800/937], d_loss: 0.1227, g_loss:4.48, D(x):0.95, D(G(z)): 0.06
# Epoch [66/200], Step [200/937], d_loss: 0.1537, g_loss:2.49, D(x):0.92, D(G(z)): 0.07
# Epoch [66/200], Step [400/937], d_loss: 0.1042, g_loss:3.73, D(x):0.94, D(G(z)): 0.04
# Epoch [66/200], Step [600/937], d_loss: 0.1428, g_loss:4.45, D(x):0.94, D(G(z)): 0.07
# Epoch [66/200], Step [800/937], d_loss: 1.3699, g_loss:3.57, D(x):0.56, D(G(z)): 0.38
# Epoch [67/200], Step [200/937], d_loss: 0.2198, g_loss:3.23, D(x):0.96, D(G(z)): 0.15
# Epoch [67/200], Step [400/937], d_loss: 0.3259, g_loss:3.07, D(x):0.90, D(G(z)): 0.18
# Epoch [67/200], Step [600/937], d_loss: 0.0417, g_loss:2.37, D(x):1.00, D(G(z)): 0.04
# Epoch [67/200], Step [800/937], d_loss: 0.3521, g_loss:3.56, D(x):0.73, D(G(z)): 0.01
# Epoch [68/200], Step [200/937], d_loss: 0.1677, g_loss:2.56, D(x):0.92, D(G(z)): 0.07
# Epoch [68/200], Step [400/937], d_loss: 0.0767, g_loss:1.45, D(x):1.00, D(G(z)): 0.07
# Epoch [68/200], Step [600/937], d_loss: 0.0696, g_loss:4.28, D(x):0.99, D(G(z)): 0.05
# Epoch [68/200], Step [800/937], d_loss: 1.2087, g_loss:5.04, D(x):1.00, D(G(z)): 0.63
# Epoch [69/200], Step [200/937], d_loss: 0.1417, g_loss:5.69, D(x):0.99, D(G(z)): 0.12
# Epoch [69/200], Step [400/937], d_loss: 0.1029, g_loss:4.95, D(x):0.99, D(G(z)): 0.09
# Epoch [69/200], Step [600/937], d_loss: 0.0121, g_loss:4.56, D(x):1.00, D(G(z)): 0.01
# Epoch [69/200], Step [800/937], d_loss: 0.3257, g_loss:1.42, D(x):1.00, D(G(z)): 0.26
# Epoch [70/200], Step [200/937], d_loss: 0.1265, g_loss:3.24, D(x):0.92, D(G(z)): 0.03
# Epoch [70/200], Step [400/937], d_loss: 0.0729, g_loss:2.08, D(x):1.00, D(G(z)): 0.07
# Epoch [70/200], Step [600/937], d_loss: 0.0501, g_loss:5.06, D(x):1.00, D(G(z)): 0.04
# Epoch [70/200], Step [800/937], d_loss: 0.1204, g_loss:3.98, D(x):1.00, D(G(z)): 0.10
# Epoch [71/200], Step [200/937], d_loss: 0.1412, g_loss:4.97, D(x):0.93, D(G(z)): 0.06
# Epoch [71/200], Step [400/937], d_loss: 0.3600, g_loss:3.88, D(x):1.00, D(G(z)): 0.27
# Epoch [71/200], Step [600/937], d_loss: 0.3250, g_loss:2.31, D(x):0.80, D(G(z)): 0.07
# Epoch [71/200], Step [800/937], d_loss: 0.2223, g_loss:2.58, D(x):0.99, D(G(z)): 0.17
# Epoch [72/200], Step [200/937], d_loss: 1.2948, g_loss:3.75, D(x):0.75, D(G(z)): 0.57
# Epoch [72/200], Step [400/937], d_loss: 0.0973, g_loss:1.03, D(x):0.93, D(G(z)): 0.02
# Epoch [72/200], Step [600/937], d_loss: 1.6816, g_loss:4.64, D(x):0.25, D(G(z)): 0.01
# Epoch [72/200], Step [800/937], d_loss: 0.2190, g_loss:1.55, D(x):0.94, D(G(z)): 0.13
# Epoch [73/200], Step [200/937], d_loss: 0.2711, g_loss:2.83, D(x):0.91, D(G(z)): 0.13
# Epoch [73/200], Step [400/937], d_loss: 0.3224, g_loss:5.18, D(x):0.79, D(G(z)): 0.06
# Epoch [73/200], Step [600/937], d_loss: 0.2728, g_loss:6.02, D(x):0.79, D(G(z)): 0.01
# Epoch [73/200], Step [800/937], d_loss: 0.0871, g_loss:2.00, D(x):0.97, D(G(z)): 0.05
# Epoch [74/200], Step [200/937], d_loss: 1.6894, g_loss:2.50, D(x):0.26, D(G(z)): 0.03
# Epoch [74/200], Step [400/937], d_loss: 0.6392, g_loss:3.39, D(x):0.62, D(G(z)): 0.04
# Epoch [74/200], Step [600/937], d_loss: 0.1356, g_loss:4.15, D(x):1.00, D(G(z)): 0.11
# Epoch [74/200], Step [800/937], d_loss: 0.1097, g_loss:3.92, D(x):1.00, D(G(z)): 0.09
# Epoch [75/200], Step [200/937], d_loss: 0.1443, g_loss:3.15, D(x):1.00, D(G(z)): 0.12
# Epoch [75/200], Step [400/937], d_loss: 0.3458, g_loss:2.47, D(x):0.90, D(G(z)): 0.19
# Epoch [75/200], Step [600/937], d_loss: 0.2889, g_loss:3.85, D(x):0.83, D(G(z)): 0.08
# Epoch [75/200], Step [800/937], d_loss: 1.7694, g_loss:1.77, D(x):0.23, D(G(z)): 0.06
# Epoch [76/200], Step [200/937], d_loss: 0.0405, g_loss:2.31, D(x):0.98, D(G(z)): 0.02
# Epoch [76/200], Step [400/937], d_loss: 0.1404, g_loss:4.57, D(x):0.91, D(G(z)): 0.04
# Epoch [76/200], Step [600/937], d_loss: 0.1241, g_loss:4.36, D(x):0.92, D(G(z)): 0.03
# Epoch [76/200], Step [800/937], d_loss: 0.1939, g_loss:5.74, D(x):1.00, D(G(z)): 0.16
# Epoch [77/200], Step [200/937], d_loss: 0.3049, g_loss:1.43, D(x):0.83, D(G(z)): 0.08
# Epoch [77/200], Step [400/937], d_loss: 0.3132, g_loss:4.34, D(x):0.76, D(G(z)): 0.01
# Epoch [77/200], Step [600/937], d_loss: 0.0877, g_loss:3.27, D(x):0.93, D(G(z)): 0.01
# Epoch [77/200], Step [800/937], d_loss: 0.2950, g_loss:2.09, D(x):0.95, D(G(z)): 0.19
# Epoch [78/200], Step [200/937], d_loss: 0.1637, g_loss:5.25, D(x):0.92, D(G(z)): 0.06
# Epoch [78/200], Step [400/937], d_loss: 0.6350, g_loss:2.41, D(x):0.72, D(G(z)): 0.15
# Epoch [78/200], Step [600/937], d_loss: 0.5010, g_loss:1.62, D(x):0.68, D(G(z)): 0.07
# Epoch [78/200], Step [800/937], d_loss: 0.1613, g_loss:1.59, D(x):0.93, D(G(z)): 0.08
# Epoch [79/200], Step [200/937], d_loss: 0.1618, g_loss:1.03, D(x):1.00, D(G(z)): 0.14
# Epoch [79/200], Step [400/937], d_loss: 0.2214, g_loss:2.74, D(x):0.88, D(G(z)): 0.08
# Epoch [79/200], Step [600/937], d_loss: 0.1532, g_loss:2.57, D(x):0.88, D(G(z)): 0.02
# Epoch [79/200], Step [800/937], d_loss: 0.2476, g_loss:4.01, D(x):0.88, D(G(z)): 0.07
# Epoch [80/200], Step [200/937], d_loss: 0.1588, g_loss:5.77, D(x):1.00, D(G(z)): 0.13
# Epoch [80/200], Step [400/937], d_loss: 0.0429, g_loss:3.08, D(x):0.97, D(G(z)): 0.01
# Epoch [80/200], Step [600/937], d_loss: 0.5465, g_loss:2.14, D(x):0.74, D(G(z)): 0.17
# Epoch [80/200], Step [800/937], d_loss: 0.2565, g_loss:4.14, D(x):0.85, D(G(z)): 0.02
# Epoch [81/200], Step [200/937], d_loss: 0.2829, g_loss:3.60, D(x):0.85, D(G(z)): 0.06
# Epoch [81/200], Step [400/937], d_loss: 1.4494, g_loss:2.43, D(x):0.31, D(G(z)): 0.00
# Epoch [81/200], Step [600/937], d_loss: 0.0428, g_loss:2.56, D(x):0.99, D(G(z)): 0.03
# Epoch [81/200], Step [800/937], d_loss: 0.2313, g_loss:3.00, D(x):0.90, D(G(z)): 0.07
# Epoch [82/200], Step [200/937], d_loss: 0.3455, g_loss:1.92, D(x):0.99, D(G(z)): 0.26
# Epoch [82/200], Step [400/937], d_loss: 0.0362, g_loss:1.62, D(x):1.00, D(G(z)): 0.03
# Epoch [82/200], Step [600/937], d_loss: 0.1925, g_loss:3.96, D(x):0.85, D(G(z)): 0.02
# Epoch [82/200], Step [800/937], d_loss: 0.2201, g_loss:2.83, D(x):1.00, D(G(z)): 0.17
# Epoch [83/200], Step [200/937], d_loss: 0.0173, g_loss:5.71, D(x):1.00, D(G(z)): 0.02
# Epoch [83/200], Step [400/937], d_loss: 0.2714, g_loss:3.95, D(x):0.85, D(G(z)): 0.08
# Epoch [83/200], Step [600/937], d_loss: 0.2141, g_loss:3.70, D(x):1.00, D(G(z)): 0.14
# Epoch [83/200], Step [800/937], d_loss: 0.0765, g_loss:3.38, D(x):0.98, D(G(z)): 0.05
# Epoch [84/200], Step [200/937], d_loss: 0.2827, g_loss:5.07, D(x):0.95, D(G(z)): 0.18
# Epoch [84/200], Step [400/937], d_loss: 0.0793, g_loss:3.06, D(x):1.00, D(G(z)): 0.07
# Epoch [84/200], Step [600/937], d_loss: 0.0427, g_loss:2.93, D(x):1.00, D(G(z)): 0.04
# Epoch [84/200], Step [800/937], d_loss: 0.9980, g_loss:3.80, D(x):0.94, D(G(z)): 0.54
# Epoch [85/200], Step [200/937], d_loss: 0.1265, g_loss:5.56, D(x):0.96, D(G(z)): 0.07
# Epoch [85/200], Step [400/937], d_loss: 0.0411, g_loss:6.30, D(x):1.00, D(G(z)): 0.03
# Epoch [85/200], Step [600/937], d_loss: 0.3799, g_loss:3.08, D(x):0.81, D(G(z)): 0.11
# Epoch [85/200], Step [800/937], d_loss: 0.3282, g_loss:4.75, D(x):0.79, D(G(z)): 0.06
# Epoch [86/200], Step [200/937], d_loss: 0.1349, g_loss:3.39, D(x):0.89, D(G(z)): 0.01
# Epoch [86/200], Step [400/937], d_loss: 0.1992, g_loss:4.04, D(x):0.93, D(G(z)): 0.11
# Epoch [86/200], Step [600/937], d_loss: 0.0314, g_loss:6.19, D(x):1.00, D(G(z)): 0.03
# Epoch [86/200], Step [800/937], d_loss: 0.3088, g_loss:3.67, D(x):1.00, D(G(z)): 0.22
# Epoch [87/200], Step [200/937], d_loss: 0.2232, g_loss:3.45, D(x):0.89, D(G(z)): 0.08
# Epoch [87/200], Step [400/937], d_loss: 0.2373, g_loss:1.12, D(x):0.99, D(G(z)): 0.19
# Epoch [87/200], Step [600/937], d_loss: 0.1141, g_loss:4.01, D(x):0.95, D(G(z)): 0.06
# Epoch [87/200], Step [800/937], d_loss: 0.0217, g_loss:4.10, D(x):0.99, D(G(z)): 0.01
# Epoch [88/200], Step [200/937], d_loss: 0.3640, g_loss:4.19, D(x):0.75, D(G(z)): 0.04
# Epoch [88/200], Step [400/937], d_loss: 0.5588, g_loss:1.89, D(x):0.63, D(G(z)): 0.04
# Epoch [88/200], Step [600/937], d_loss: 0.3388, g_loss:2.48, D(x):0.83, D(G(z)): 0.12
# Epoch [88/200], Step [800/937], d_loss: 0.2988, g_loss:4.21, D(x):0.77, D(G(z)): 0.01
# Epoch [89/200], Step [200/937], d_loss: 1.1478, g_loss:5.44, D(x):0.99, D(G(z)): 0.59
# Epoch [89/200], Step [400/937], d_loss: 0.1569, g_loss:4.19, D(x):0.95, D(G(z)): 0.04
# Epoch [89/200], Step [600/937], d_loss: 0.0581, g_loss:0.76, D(x):1.00, D(G(z)): 0.05
# Epoch [89/200], Step [800/937], d_loss: 0.1994, g_loss:1.76, D(x):0.87, D(G(z)): 0.05
# Epoch [90/200], Step [200/937], d_loss: 0.2457, g_loss:1.67, D(x):0.83, D(G(z)): 0.03
# Epoch [90/200], Step [400/937], d_loss: 0.5251, g_loss:2.66, D(x):0.99, D(G(z)): 0.36
# Epoch [90/200], Step [600/937], d_loss: 0.0618, g_loss:3.02, D(x):0.97, D(G(z)): 0.03
# Epoch [90/200], Step [800/937], d_loss: 0.6093, g_loss:3.58, D(x):0.99, D(G(z)): 0.39
# Epoch [91/200], Step [200/937], d_loss: 0.4738, g_loss:2.92, D(x):0.90, D(G(z)): 0.28
# Epoch [91/200], Step [400/937], d_loss: 0.8861, g_loss:4.18, D(x):0.89, D(G(z)): 0.45
# Epoch [91/200], Step [600/937], d_loss: 0.2502, g_loss:3.79, D(x):0.99, D(G(z)): 0.19
# Epoch [91/200], Step [800/937], d_loss: 0.2059, g_loss:3.75, D(x):0.86, D(G(z)): 0.04
# Epoch [92/200], Step [200/937], d_loss: 0.1290, g_loss:4.66, D(x):0.97, D(G(z)): 0.09
# Epoch [92/200], Step [400/937], d_loss: 0.1584, g_loss:3.73, D(x):0.95, D(G(z)): 0.09
# Epoch [92/200], Step [600/937], d_loss: 0.0310, g_loss:3.77, D(x):0.99, D(G(z)): 0.02
# Epoch [92/200], Step [800/937], d_loss: 0.0786, g_loss:2.44, D(x):0.98, D(G(z)): 0.05
# Epoch [93/200], Step [200/937], d_loss: 0.3621, g_loss:3.71, D(x):1.00, D(G(z)): 0.28
# Epoch [93/200], Step [400/937], d_loss: 0.0246, g_loss:1.65, D(x):1.00, D(G(z)): 0.02
# Epoch [93/200], Step [600/937], d_loss: 2.6860, g_loss:2.68, D(x):0.12, D(G(z)): 0.00
# Epoch [93/200], Step [800/937], d_loss: 0.2773, g_loss:2.14, D(x):0.79, D(G(z)): 0.03
# Epoch [94/200], Step [200/937], d_loss: 0.4698, g_loss:3.01, D(x):0.70, D(G(z)): 0.01
# Epoch [94/200], Step [400/937], d_loss: 0.9444, g_loss:5.95, D(x):0.98, D(G(z)): 0.52
# Epoch [94/200], Step [600/937], d_loss: 0.0069, g_loss:6.37, D(x):1.00, D(G(z)): 0.01
# Epoch [94/200], Step [800/937], d_loss: 0.4351, g_loss:2.88, D(x):0.92, D(G(z)): 0.25
# Epoch [95/200], Step [200/937], d_loss: 0.1260, g_loss:3.15, D(x):0.90, D(G(z)): 0.02
# Epoch [95/200], Step [400/937], d_loss: 0.5776, g_loss:1.70, D(x):0.66, D(G(z)): 0.07
# Epoch [95/200], Step [600/937], d_loss: 0.1815, g_loss:2.26, D(x):0.99, D(G(z)): 0.15
# Epoch [95/200], Step [800/937], d_loss: 0.0759, g_loss:3.89, D(x):1.00, D(G(z)): 0.07
# Epoch [96/200], Step [200/937], d_loss: 0.2418, g_loss:3.54, D(x):0.96, D(G(z)): 0.16
# Epoch [96/200], Step [400/937], d_loss: 0.0432, g_loss:6.81, D(x):0.99, D(G(z)): 0.04
# Epoch [96/200], Step [600/937], d_loss: 0.3890, g_loss:0.65, D(x):0.75, D(G(z)): 0.04
# Epoch [96/200], Step [800/937], d_loss: 0.3334, g_loss:3.72, D(x):0.75, D(G(z)): 0.01
# Epoch [97/200], Step [200/937], d_loss: 0.5246, g_loss:3.63, D(x):0.68, D(G(z)): 0.03
# Epoch [97/200], Step [400/937], d_loss: 0.0064, g_loss:7.47, D(x):0.99, D(G(z)): 0.00
# Epoch [97/200], Step [600/937], d_loss: 0.0725, g_loss:2.39, D(x):0.99, D(G(z)): 0.06
# Epoch [97/200], Step [800/937], d_loss: 0.6167, g_loss:1.38, D(x):0.62, D(G(z)): 0.03
# Epoch [98/200], Step [200/937], d_loss: 0.2033, g_loss:5.67, D(x):0.96, D(G(z)): 0.13
# Epoch [98/200], Step [400/937], d_loss: 0.3782, g_loss:4.89, D(x):0.86, D(G(z)): 0.18
# Epoch [98/200], Step [600/937], d_loss: 0.0637, g_loss:4.76, D(x):0.98, D(G(z)): 0.04
# Epoch [98/200], Step [800/937], d_loss: 0.1525, g_loss:2.74, D(x):0.98, D(G(z)): 0.12
# Epoch [99/200], Step [200/937], d_loss: 0.2350, g_loss:1.64, D(x):0.91, D(G(z)): 0.11
# Epoch [99/200], Step [400/937], d_loss: 0.1712, g_loss:5.17, D(x):0.86, D(G(z)): 0.01
# Epoch [99/200], Step [600/937], d_loss: 0.2333, g_loss:3.74, D(x):0.84, D(G(z)): 0.03
# Epoch [99/200], Step [800/937], d_loss: 0.0733, g_loss:4.07, D(x):0.98, D(G(z)): 0.05
# Epoch [100/200], Step [200/937], d_loss: 0.3131, g_loss:5.75, D(x):0.96, D(G(z)): 0.19
# Epoch [100/200], Step [400/937], d_loss: 0.0713, g_loss:3.36, D(x):0.95, D(G(z)): 0.02
# Epoch [100/200], Step [600/937], d_loss: 0.3692, g_loss:1.67, D(x):0.75, D(G(z)): 0.04
# Epoch [100/200], Step [800/937], d_loss: 0.3510, g_loss:3.10, D(x):0.80, D(G(z)): 0.09
# Epoch [101/200], Step [200/937], d_loss: 0.2935, g_loss:5.38, D(x):0.80, D(G(z)): 0.01
# Epoch [101/200], Step [400/937], d_loss: 0.1921, g_loss:0.30, D(x):0.85, D(G(z)): 0.02
# Epoch [101/200], Step [600/937], d_loss: 0.1264, g_loss:5.25, D(x):1.00, D(G(z)): 0.11
# Epoch [101/200], Step [800/937], d_loss: 0.2447, g_loss:3.48, D(x):0.85, D(G(z)): 0.06
# Epoch [102/200], Step [200/937], d_loss: 0.1006, g_loss:4.46, D(x):0.94, D(G(z)): 0.03
# Epoch [102/200], Step [400/937], d_loss: 0.1499, g_loss:3.33, D(x):0.93, D(G(z)): 0.03
# Epoch [102/200], Step [600/937], d_loss: 0.4223, g_loss:6.14, D(x):0.71, D(G(z)): 0.01
# Epoch [102/200], Step [800/937], d_loss: 0.1111, g_loss:1.58, D(x):1.00, D(G(z)): 0.10
# Epoch [103/200], Step [200/937], d_loss: 0.3302, g_loss:3.13, D(x):1.00, D(G(z)): 0.19
# Epoch [103/200], Step [400/937], d_loss: 0.6744, g_loss:3.94, D(x):0.98, D(G(z)): 0.43
# Epoch [103/200], Step [600/937], d_loss: 0.9066, g_loss:4.36, D(x):0.99, D(G(z)): 0.55
# Epoch [103/200], Step [800/937], d_loss: 0.1079, g_loss:3.28, D(x):0.92, D(G(z)): 0.02
# Epoch [104/200], Step [200/937], d_loss: 0.3317, g_loss:3.64, D(x):0.90, D(G(z)): 0.19
# Epoch [104/200], Step [400/937], d_loss: 0.3453, g_loss:4.10, D(x):0.74, D(G(z)): 0.01
# Epoch [104/200], Step [600/937], d_loss: 0.5419, g_loss:4.04, D(x):0.96, D(G(z)): 0.35
# Epoch [104/200], Step [800/937], d_loss: 2.2760, g_loss:4.77, D(x):0.34, D(G(z)): 0.53

# %%
import torch
print(torch.Tensor([0.51]).round())
# Out:
# tensor([1.])
