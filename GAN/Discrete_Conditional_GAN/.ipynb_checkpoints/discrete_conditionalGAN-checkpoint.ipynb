# %%
import os
import numpy as np
import math
from torchvision import transforms, datasets
from torchvision.utils import save_image
from torch.utils.data import DataLoader

import torch.nn as nn
import torch.nn.functional as F
import torch
img_save_path = './conditionalGAN/images/'
os.makedirs(img_save_path, exist_ok=True)

n_epochs = 200 # number of epochs of training
batch_size = 64 # size of the batches
lr = 0.0002 # learning rate
beta1 = 0.5 # decay of the first order mmomentum of gradient
beta2 = 0.999 # decay of second order momentum of gradient
latent_dim = 100 # dim of the latent space
n_classes = 10 # number of classes for dataset
image_size = 28 # size of each image dimension
channels = 1 # number of image channels
sample_interval = 200 # interval between image sampling
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        torch.nn.init.normal(m.weight,0.0,0.02)
    elif classname.find('BatchNorm2d')!=-1:
        torch.nn.init.normal(m.weight,1.0,0.02)
        torch.nn.init.constant(m.bias,0.0)
        
def idx2onehot(idx, n):
    assert torch.max(idx).item() < n and idx.dim() == 1
    idx2dim = idx.view(-1,1) # change from 1-dim tensor to 2-dim tensor
    onehot = torch.zeros(idx2dim.size(0),n).scatter_(1,idx2dim,1)

    return onehot


    
class Generator(nn.Module):
    # initializers
    def __init__(self):
        super().__init__()
        self.fc1_1 = nn.Linear(latent_dim,256)
        self.fc1_1_bn = nn.BatchNorm1d(256)
        self.fc1_2 = nn.Linear(10, 256)
        self.fc1_2_bn = nn.BatchNorm1d(256)
        self.fc2 = nn.Linear(512,512)
        self.fc2_bn = nn.BatchNorm1d(512)
        self.fc3 = nn.Linear(512,1024)
        self.fc3_bn = nn.BatchNorm1d(1024)
        self.fc4 = nn.Linear(1024,image_size**2)
    
    # forward method
    def forward(self, z, y):
        x1 = F.relu(self.fc1_1_bn(self.fc1_1(z)))
        x2 = F.relu(self.fc1_2_bn(self.fc1_2(y)))
        x = torch.cat([x1, x2], dim = 1)
        x = F.relu(self.fc2_bn(self.fc2(x)))
        x = F.relu(self.fc3_bn(self.fc3(x)))
        x = torch.tanh(self.fc4(x))
        return x
    
class Discriminator(nn.Module):
    # initializers
    def __init__(self):
        super().__init__()
        self.fc1_1 = nn.Linear(image_size**2, 1024)
        self.fc1_2 = nn.Linear(10, 1024)
        self.fc2 = nn.Linear(2048, 512)
        self.fc2_bn = nn.BatchNorm1d(512)
        self.fc3 = nn.Linear(512,256)
        self.fc3_bn = nn.BatchNorm1d(256)
        self.fc4 = nn.Linear(256, 1)
        
        # forward method
    def forward(self, input, y):
        x1 = F.leaky_relu(self.fc1_1(input), 0.2)
        x2 = F.leaky_relu(self.fc1_2(y),0.2)
        x = torch.cat([x1, x2], dim = 1)
        x = F.leaky_relu(self.fc2_bn(self.fc2(x)),0.2)
        x = F.leaky_relu(self.fc3_bn(self.fc3(x)),0.2)
        x = torch.sigmoid(self.fc4(x))
        return x
        
# Loss function
loss = torch.nn.BCELoss()

# Initialize Generator and discriminator
generator = Generator()
discriminator = Discriminator()

# Move model to the corresponding device
generator.to(device)
discriminator.to(device)

# Initialize weights
#generator.apply(weights_init_normal)
#discriminator.apply(weights_init_normal)

data_save_path = './conditionalGAN/data/'
os.makedirs(data_save_path, exist_ok = True)

transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*channels,[0.5]*channels)
])
dataset = datasets.MNIST(root = data_save_path, train = True, download = True, transform=transform)


dataloader = DataLoader(dataset,batch_size = batch_size,shuffle=True,drop_last = True)
print("the data is OK")
# Out:
# 0.1%
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./conditionalGAN/data/MNIST/raw/train-images-idx3-ubyte.gz
# 100.1%
# Extracting ./conditionalGAN/data/MNIST/raw/train-images-idx3-ubyte.gz to ./conditionalGAN/data/MNIST/raw
# 28.4%
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./conditionalGAN/data/MNIST/raw/train-labels-idx1-ubyte.gz
# 0.5%5%
# Extracting ./conditionalGAN/data/MNIST/raw/train-labels-idx1-ubyte.gz to ./conditionalGAN/data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./conditionalGAN/data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.4%
# Extracting ./conditionalGAN/data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./conditionalGAN/data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./conditionalGAN/data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 180.4%
# Extracting ./conditionalGAN/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./conditionalGAN/data/MNIST/raw
# Processing...
# Done!
# the data is OK

# %%
# Optimizers
optimizer_G = torch.optim.Adam(generator.parameters(),lr = lr, betas = (beta1, beta2))
optimizer_D = torch.optim.Adam(discriminator.parameters(),lr = lr, betas = (beta1, beta2))
def reset_grad():
    optimizer_D.zero_grad()
    optimizer_G.zero_grad()

# %%
def sample_image(n_row, n_col,epoch):
    """Saves a grid of generated digits ranging from 0 to n_classes"""
    # Sample noise
    z = torch.randn(n_row*n_col, latent_dim).to(device)
    # Get labels ranging from 0 to n_classes for n rows
    labels = torch.Tensor([num for _ in range(n_col) for num in range(n_row)]).type(torch.LongTensor)
    labels = idx2onehot(labels,n_classes).to(device)
    gen_imgs = generator(z, labels).view(z.size(0),channels,image_size,image_size) # reshape the output of the generator
    save_image(gen_imgs.data, os.path.join(img_save_path,'{}.png'.format(epoch)),nrow=n_row, normalize=True)

# %%
total_step = len(dataloader)

for epoch in range(n_epochs):
    for i, (images, labels) in enumerate(dataloader):
        images = images.view(images.size(0), -1).to(device)
        
        real_labels = torch.ones(batch_size,1).to(device)
        fake_labels = torch.zeros(batch_size,1).to(device)
        
        # Configure labels
        
        labels_onehot = idx2onehot(labels,n_classes).to(device)

        
        # =============================================
        #
        #  Training Discriminator 
        #
        # =============================================
        
        outputs = discriminator(images,labels_onehot)
        d_loss_real = loss(outputs, real_labels)
        real_score = outputs # just for the purpose of tracking training progress
        
        z = torch.randn(batch_size, latent_dim).to(device)
        label_z = idx2onehot(torch.randint(n_classes,(batch_size,)),n_classes).to(device)
        
        fake_images = generator(z,label_z).detach()
        outputs = discriminator(fake_images,label_z)
        d_loss_fake = loss(outputs, fake_labels)
        fake_score = outputs # just for the purpose of tracking training progress
        
        # Backprop and optimize
        d_loss = d_loss_real + d_loss_fake
        reset_grad() # reset stored gradients
        d_loss.backward()
        optimizer_D.step()
        
        
        # =============================================
        #
        #  Training Generator
        #
        # ============================================
        
        z = torch.randn(batch_size, latent_dim).to(device)
        label_z = idx2onehot(torch.randint(n_classes,(batch_size,)),n_classes).to(device)

        fake_images = generator(z,label_z)
        outputs = discriminator(fake_images,label_z)
        g_loss = loss(outputs, real_labels)
        reset_grad()
        g_loss.backward()
        optimizer_G.step()
        
        if (i+1) % sample_interval == 0:
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss:{:.2f}, D(G(z)): {:.2f}'.format(epoch, n_epochs, i+1, total_step, d_loss.item(), g_loss.item(), real_score.mean().item(), fake_score.mean().item()))
          
    sample_image(n_row=10,n_col=10,epoch=epoch)
# Out:
# Epoch [0/200], Step [200/937], d_loss: 0.9844, g_loss:0.83, D(G(z)): 0.60
# Epoch [0/200], Step [400/937], d_loss: 1.0356, g_loss:1.09, D(G(z)): 0.63
# Epoch [0/200], Step [600/937], d_loss: 1.3081, g_loss:0.89, D(G(z)): 0.51
# Epoch [0/200], Step [800/937], d_loss: 1.0311, g_loss:1.09, D(G(z)): 0.63
# Epoch [1/200], Step [200/937], d_loss: 1.2091, g_loss:0.91, D(G(z)): 0.56
# Epoch [1/200], Step [400/937], d_loss: 1.0780, g_loss:1.02, D(G(z)): 0.59
# Epoch [1/200], Step [600/937], d_loss: 1.1574, g_loss:1.04, D(G(z)): 0.54
# Epoch [1/200], Step [800/937], d_loss: 1.1214, g_loss:1.16, D(G(z)): 0.63
# Epoch [2/200], Step [200/937], d_loss: 1.0272, g_loss:1.29, D(G(z)): 0.55
# Epoch [2/200], Step [400/937], d_loss: 1.0769, g_loss:1.13, D(G(z)): 0.66
# Epoch [2/200], Step [600/937], d_loss: 0.8803, g_loss:0.99, D(G(z)): 0.55
# Epoch [2/200], Step [800/937], d_loss: 0.6323, g_loss:1.69, D(G(z)): 0.76
# Epoch [3/200], Step [200/937], d_loss: 0.8940, g_loss:1.19, D(G(z)): 0.68
# Epoch [3/200], Step [400/937], d_loss: 1.3010, g_loss:0.97, D(G(z)): 0.73
# Epoch [3/200], Step [600/937], d_loss: 1.0797, g_loss:1.58, D(G(z)): 0.75
# Epoch [3/200], Step [800/937], d_loss: 1.0608, g_loss:1.73, D(G(z)): 0.58
# Epoch [4/200], Step [200/937], d_loss: 1.0878, g_loss:2.03, D(G(z)): 0.71
# Epoch [4/200], Step [400/937], d_loss: 0.7697, g_loss:1.76, D(G(z)): 0.85
# Epoch [4/200], Step [600/937], d_loss: 0.5955, g_loss:1.76, D(G(z)): 0.80
# Epoch [4/200], Step [800/937], d_loss: 0.6155, g_loss:2.03, D(G(z)): 0.74
# Epoch [5/200], Step [200/937], d_loss: 0.4886, g_loss:1.21, D(G(z)): 0.78
# Epoch [5/200], Step [400/937], d_loss: 0.4212, g_loss:2.83, D(G(z)): 0.73
# Epoch [5/200], Step [600/937], d_loss: 0.7454, g_loss:0.98, D(G(z)): 0.72
# Epoch [5/200], Step [800/937], d_loss: 1.0061, g_loss:1.10, D(G(z)): 0.78
# Epoch [6/200], Step [200/937], d_loss: 1.4843, g_loss:2.08, D(G(z)): 0.32
# Epoch [6/200], Step [400/937], d_loss: 0.6389, g_loss:1.20, D(G(z)): 0.69
# Epoch [6/200], Step [600/937], d_loss: 1.0567, g_loss:1.76, D(G(z)): 0.65
# Epoch [6/200], Step [800/937], d_loss: 0.6884, g_loss:0.91, D(G(z)): 0.65
# Epoch [7/200], Step [200/937], d_loss: 1.0502, g_loss:1.30, D(G(z)): 0.68
# Epoch [7/200], Step [400/937], d_loss: 0.7258, g_loss:0.86, D(G(z)): 0.73
# Epoch [7/200], Step [600/937], d_loss: 0.9387, g_loss:1.00, D(G(z)): 0.60
# Epoch [7/200], Step [800/937], d_loss: 1.1797, g_loss:1.53, D(G(z)): 0.57
# Epoch [8/200], Step [200/937], d_loss: 1.0009, g_loss:1.44, D(G(z)): 0.69
# Epoch [8/200], Step [400/937], d_loss: 1.1285, g_loss:1.60, D(G(z)): 0.79
# Epoch [8/200], Step [600/937], d_loss: 1.1058, g_loss:0.85, D(G(z)): 0.62
# Epoch [8/200], Step [800/937], d_loss: 0.9484, g_loss:0.81, D(G(z)): 0.64
# Epoch [9/200], Step [200/937], d_loss: 1.0084, g_loss:1.84, D(G(z)): 0.58
# Epoch [9/200], Step [400/937], d_loss: 0.9107, g_loss:1.19, D(G(z)): 0.59
# Epoch [9/200], Step [600/937], d_loss: 0.9986, g_loss:1.47, D(G(z)): 0.66
# Epoch [9/200], Step [800/937], d_loss: 0.9034, g_loss:2.02, D(G(z)): 0.62
# Epoch [10/200], Step [200/937], d_loss: 1.2320, g_loss:1.35, D(G(z)): 0.66
# Epoch [10/200], Step [400/937], d_loss: 0.8763, g_loss:1.49, D(G(z)): 0.61
# Epoch [10/200], Step [600/937], d_loss: 0.6905, g_loss:0.75, D(G(z)): 0.67
# Epoch [10/200], Step [800/937], d_loss: 0.4897, g_loss:2.28, D(G(z)): 0.76
# Epoch [11/200], Step [200/937], d_loss: 0.6532, g_loss:2.00, D(G(z)): 0.82
# Epoch [11/200], Step [400/937], d_loss: 0.9671, g_loss:1.05, D(G(z)): 0.48
# Epoch [11/200], Step [600/937], d_loss: 0.5164, g_loss:1.45, D(G(z)): 0.69
# Epoch [11/200], Step [800/937], d_loss: 0.5860, g_loss:1.04, D(G(z)): 0.72
# Epoch [12/200], Step [200/937], d_loss: 0.9263, g_loss:1.12, D(G(z)): 0.58
# Epoch [12/200], Step [400/937], d_loss: 1.0046, g_loss:1.21, D(G(z)): 0.54
# Epoch [12/200], Step [600/937], d_loss: 1.2564, g_loss:1.61, D(G(z)): 0.68
# Epoch [12/200], Step [800/937], d_loss: 0.8707, g_loss:0.89, D(G(z)): 0.63
# Epoch [13/200], Step [200/937], d_loss: 1.3789, g_loss:1.23, D(G(z)): 0.69
# Epoch [13/200], Step [400/937], d_loss: 1.1141, g_loss:1.29, D(G(z)): 0.58
# Epoch [13/200], Step [600/937], d_loss: 1.1711, g_loss:0.94, D(G(z)): 0.59
# Epoch [13/200], Step [800/937], d_loss: 0.9936, g_loss:1.75, D(G(z)): 0.74
# Epoch [14/200], Step [200/937], d_loss: 1.4530, g_loss:1.21, D(G(z)): 0.61
# Epoch [14/200], Step [400/937], d_loss: 1.0740, g_loss:1.29, D(G(z)): 0.72
# Epoch [14/200], Step [600/937], d_loss: 0.9598, g_loss:1.38, D(G(z)): 0.70
# Epoch [14/200], Step [800/937], d_loss: 0.9443, g_loss:1.19, D(G(z)): 0.59
# Epoch [15/200], Step [200/937], d_loss: 1.2086, g_loss:0.77, D(G(z)): 0.63
# Epoch [15/200], Step [400/937], d_loss: 0.8287, g_loss:0.64, D(G(z)): 0.74
# Epoch [15/200], Step [600/937], d_loss: 0.8603, g_loss:1.20, D(G(z)): 0.62
# Epoch [15/200], Step [800/937], d_loss: 0.6335, g_loss:1.06, D(G(z)): 0.74
# Epoch [16/200], Step [200/937], d_loss: 1.0327, g_loss:1.00, D(G(z)): 0.65
# Epoch [16/200], Step [400/937], d_loss: 1.1173, g_loss:1.38, D(G(z)): 0.67
# Epoch [16/200], Step [600/937], d_loss: 0.8210, g_loss:2.17, D(G(z)): 0.83
# Epoch [16/200], Step [800/937], d_loss: 0.9496, g_loss:1.50, D(G(z)): 0.78
# Epoch [17/200], Step [200/937], d_loss: 1.3986, g_loss:1.18, D(G(z)): 0.38
# Epoch [17/200], Step [400/937], d_loss: 1.2972, g_loss:1.29, D(G(z)): 0.60
# Epoch [17/200], Step [600/937], d_loss: 1.1407, g_loss:0.96, D(G(z)): 0.56
# Epoch [17/200], Step [800/937], d_loss: 0.6314, g_loss:0.98, D(G(z)): 0.75
# Epoch [18/200], Step [200/937], d_loss: 0.5529, g_loss:1.44, D(G(z)): 0.70
# Epoch [18/200], Step [400/937], d_loss: 0.8721, g_loss:3.44, D(G(z)): 0.94
# Epoch [18/200], Step [600/937], d_loss: 0.2151, g_loss:4.06, D(G(z)): 0.94
# Epoch [18/200], Step [800/937], d_loss: 0.6019, g_loss:1.08, D(G(z)): 0.70
# Epoch [19/200], Step [200/937], d_loss: 0.6499, g_loss:1.64, D(G(z)): 0.81
# Epoch [19/200], Step [400/937], d_loss: 0.6363, g_loss:1.67, D(G(z)): 0.72
# Epoch [19/200], Step [600/937], d_loss: 0.6625, g_loss:3.17, D(G(z)): 0.86
# Epoch [19/200], Step [800/937], d_loss: 0.9498, g_loss:1.79, D(G(z)): 0.86
# Epoch [20/200], Step [200/937], d_loss: 0.3549, g_loss:1.99, D(G(z)): 0.89
# Epoch [20/200], Step [400/937], d_loss: 0.9494, g_loss:1.19, D(G(z)): 0.60
# Epoch [20/200], Step [600/937], d_loss: 0.8225, g_loss:1.03, D(G(z)): 0.61
# Epoch [20/200], Step [800/937], d_loss: 0.6056, g_loss:1.70, D(G(z)): 0.83
# Epoch [21/200], Step [200/937], d_loss: 0.4766, g_loss:2.56, D(G(z)): 0.91
# Epoch [21/200], Step [400/937], d_loss: 0.6590, g_loss:1.68, D(G(z)): 0.78
# Epoch [21/200], Step [600/937], d_loss: 0.6397, g_loss:2.02, D(G(z)): 0.91
# Epoch [21/200], Step [800/937], d_loss: 0.5627, g_loss:2.43, D(G(z)): 0.84
# Epoch [22/200], Step [200/937], d_loss: 0.5021, g_loss:1.69, D(G(z)): 0.80
# Epoch [22/200], Step [400/937], d_loss: 0.5444, g_loss:1.47, D(G(z)): 0.89
# Epoch [22/200], Step [600/937], d_loss: 0.7592, g_loss:1.63, D(G(z)): 0.56
# Epoch [22/200], Step [800/937], d_loss: 0.3771, g_loss:2.18, D(G(z)): 0.86
# Epoch [23/200], Step [200/937], d_loss: 1.0567, g_loss:1.02, D(G(z)): 0.46
# Epoch [23/200], Step [400/937], d_loss: 0.4132, g_loss:2.93, D(G(z)): 0.79
# Epoch [23/200], Step [600/937], d_loss: 0.4981, g_loss:1.51, D(G(z)): 0.84
# Epoch [23/200], Step [800/937], d_loss: 0.4827, g_loss:1.29, D(G(z)): 0.75
# Epoch [24/200], Step [200/937], d_loss: 0.8612, g_loss:2.34, D(G(z)): 0.83
# Epoch [24/200], Step [400/937], d_loss: 0.4423, g_loss:2.44, D(G(z)): 0.77
# Epoch [24/200], Step [600/937], d_loss: 0.5722, g_loss:2.15, D(G(z)): 0.90
# Epoch [24/200], Step [800/937], d_loss: 0.6602, g_loss:2.21, D(G(z)): 0.71
# Epoch [25/200], Step [200/937], d_loss: 0.2726, g_loss:1.74, D(G(z)): 0.87
# Epoch [25/200], Step [400/937], d_loss: 0.3969, g_loss:1.94, D(G(z)): 0.84
# Epoch [25/200], Step [600/937], d_loss: 0.2774, g_loss:1.67, D(G(z)): 0.84
# Epoch [25/200], Step [800/937], d_loss: 0.2523, g_loss:0.97, D(G(z)): 0.93
# Epoch [26/200], Step [200/937], d_loss: 0.8722, g_loss:2.62, D(G(z)): 0.68
# Epoch [26/200], Step [400/937], d_loss: 0.8571, g_loss:2.23, D(G(z)): 0.57
# Epoch [26/200], Step [600/937], d_loss: 0.3493, g_loss:3.70, D(G(z)): 0.95
# Epoch [26/200], Step [800/937], d_loss: 0.2455, g_loss:2.29, D(G(z)): 0.90
# Epoch [27/200], Step [200/937], d_loss: 0.3464, g_loss:1.57, D(G(z)): 0.91
# Epoch [27/200], Step [400/937], d_loss: 0.4116, g_loss:1.98, D(G(z)): 0.73
# Epoch [27/200], Step [600/937], d_loss: 0.9508, g_loss:1.02, D(G(z)): 0.49
# Epoch [27/200], Step [800/937], d_loss: 0.3123, g_loss:3.36, D(G(z)): 0.98
# Epoch [28/200], Step [200/937], d_loss: 0.2040, g_loss:2.84, D(G(z)): 0.87
# Epoch [28/200], Step [400/937], d_loss: 0.3517, g_loss:2.64, D(G(z)): 0.78
# Epoch [28/200], Step [600/937], d_loss: 0.2281, g_loss:2.54, D(G(z)): 0.89
# Epoch [28/200], Step [800/937], d_loss: 0.1636, g_loss:1.99, D(G(z)): 0.92
# Epoch [29/200], Step [200/937], d_loss: 0.2990, g_loss:4.29, D(G(z)): 0.80
# Epoch [29/200], Step [400/937], d_loss: 0.2568, g_loss:3.28, D(G(z)): 0.86
# Epoch [29/200], Step [600/937], d_loss: 0.3882, g_loss:1.99, D(G(z)): 0.82
# Epoch [29/200], Step [800/937], d_loss: 0.3465, g_loss:1.73, D(G(z)): 0.84
# Epoch [30/200], Step [200/937], d_loss: 0.7885, g_loss:3.39, D(G(z)): 0.84
# Epoch [30/200], Step [400/937], d_loss: 0.3023, g_loss:1.99, D(G(z)): 0.87
# Epoch [30/200], Step [600/937], d_loss: 0.4530, g_loss:2.07, D(G(z)): 0.74
# Epoch [30/200], Step [800/937], d_loss: 0.9570, g_loss:2.33, D(G(z)): 0.52
# Epoch [31/200], Step [200/937], d_loss: 0.8474, g_loss:1.03, D(G(z)): 0.57
# Epoch [31/200], Step [400/937], d_loss: 0.3760, g_loss:2.16, D(G(z)): 0.81
# Epoch [31/200], Step [600/937], d_loss: 0.3726, g_loss:3.75, D(G(z)): 0.77
# Epoch [31/200], Step [800/937], d_loss: 0.6602, g_loss:3.42, D(G(z)): 0.82
# Epoch [32/200], Step [200/937], d_loss: 0.6753, g_loss:1.99, D(G(z)): 0.58
# Epoch [32/200], Step [400/937], d_loss: 0.4217, g_loss:2.20, D(G(z)): 0.74
# Epoch [32/200], Step [600/937], d_loss: 0.2849, g_loss:2.49, D(G(z)): 0.83
# Epoch [32/200], Step [800/937], d_loss: 0.1541, g_loss:2.00, D(G(z)): 0.95
# Epoch [33/200], Step [200/937], d_loss: 0.6573, g_loss:1.41, D(G(z)): 0.61
# Epoch [33/200], Step [400/937], d_loss: 0.4147, g_loss:2.61, D(G(z)): 0.84
# Epoch [33/200], Step [600/937], d_loss: 0.8898, g_loss:3.38, D(G(z)): 0.94
# Epoch [33/200], Step [800/937], d_loss: 0.4284, g_loss:2.81, D(G(z)): 0.79
# Epoch [34/200], Step [200/937], d_loss: 0.5311, g_loss:2.25, D(G(z)): 0.83
# Epoch [34/200], Step [400/937], d_loss: 0.2014, g_loss:2.73, D(G(z)): 0.93
# Epoch [34/200], Step [600/937], d_loss: 0.2402, g_loss:3.42, D(G(z)): 0.89
# Epoch [34/200], Step [800/937], d_loss: 0.3006, g_loss:2.57, D(G(z)): 0.94
# Epoch [35/200], Step [200/937], d_loss: 0.3491, g_loss:1.38, D(G(z)): 0.80
# Epoch [35/200], Step [400/937], d_loss: 0.3611, g_loss:3.14, D(G(z)): 0.97
# Epoch [35/200], Step [600/937], d_loss: 0.3741, g_loss:2.33, D(G(z)): 0.94
# Epoch [35/200], Step [800/937], d_loss: 0.1891, g_loss:3.86, D(G(z)): 0.85
# Epoch [36/200], Step [200/937], d_loss: 0.6475, g_loss:1.36, D(G(z)): 0.60
# Epoch [36/200], Step [400/937], d_loss: 0.4491, g_loss:3.16, D(G(z)): 0.91
# Epoch [36/200], Step [600/937], d_loss: 0.3333, g_loss:4.56, D(G(z)): 0.97
# Epoch [36/200], Step [800/937], d_loss: 0.3784, g_loss:1.91, D(G(z)): 0.87
# Epoch [37/200], Step [200/937], d_loss: 0.3311, g_loss:3.61, D(G(z)): 0.97
# Epoch [37/200], Step [400/937], d_loss: 0.0845, g_loss:2.74, D(G(z)): 0.98
# Epoch [37/200], Step [600/937], d_loss: 0.1263, g_loss:2.24, D(G(z)): 0.94
# Epoch [37/200], Step [800/937], d_loss: 0.3481, g_loss:2.81, D(G(z)): 0.90
# Epoch [38/200], Step [200/937], d_loss: 0.2436, g_loss:2.50, D(G(z)): 0.87
# Epoch [38/200], Step [400/937], d_loss: 0.1474, g_loss:1.86, D(G(z)): 0.98
# Epoch [38/200], Step [600/937], d_loss: 0.8377, g_loss:2.57, D(G(z)): 0.51
# Epoch [38/200], Step [800/937], d_loss: 0.3848, g_loss:1.78, D(G(z)): 0.75
# Epoch [39/200], Step [200/937], d_loss: 0.2536, g_loss:1.37, D(G(z)): 0.96
# Epoch [39/200], Step [400/937], d_loss: 0.3216, g_loss:3.25, D(G(z)): 0.87
# Epoch [39/200], Step [600/937], d_loss: 0.3343, g_loss:2.67, D(G(z)): 0.85
# Epoch [39/200], Step [800/937], d_loss: 0.5020, g_loss:2.51, D(G(z)): 0.68
# Epoch [40/200], Step [200/937], d_loss: 0.6863, g_loss:2.33, D(G(z)): 0.87
# Epoch [40/200], Step [400/937], d_loss: 0.5203, g_loss:3.51, D(G(z)): 0.81
# Epoch [40/200], Step [600/937], d_loss: 0.2342, g_loss:2.71, D(G(z)): 0.85
# Epoch [40/200], Step [800/937], d_loss: 0.0756, g_loss:2.84, D(G(z)): 0.97
# Epoch [41/200], Step [200/937], d_loss: 0.1591, g_loss:3.90, D(G(z)): 0.91
# Epoch [41/200], Step [400/937], d_loss: 0.2820, g_loss:3.80, D(G(z)): 0.90
# Epoch [41/200], Step [600/937], d_loss: 0.1798, g_loss:3.07, D(G(z)): 0.96
# Epoch [41/200], Step [800/937], d_loss: 0.2961, g_loss:2.69, D(G(z)): 0.82
# Epoch [42/200], Step [200/937], d_loss: 0.4599, g_loss:3.05, D(G(z)): 0.88
# Epoch [42/200], Step [400/937], d_loss: 0.3919, g_loss:3.53, D(G(z)): 0.76
# Epoch [42/200], Step [600/937], d_loss: 0.3022, g_loss:2.50, D(G(z)): 0.98
# Epoch [42/200], Step [800/937], d_loss: 0.1537, g_loss:2.47, D(G(z)): 0.96
# Epoch [43/200], Step [200/937], d_loss: 0.6367, g_loss:2.49, D(G(z)): 0.88
# Epoch [43/200], Step [400/937], d_loss: 0.0740, g_loss:2.96, D(G(z)): 0.97
# Epoch [43/200], Step [600/937], d_loss: 0.2329, g_loss:3.89, D(G(z)): 0.88
# Epoch [43/200], Step [800/937], d_loss: 0.1650, g_loss:3.06, D(G(z)): 0.92
# Epoch [44/200], Step [200/937], d_loss: 0.4159, g_loss:4.49, D(G(z)): 0.84
# Epoch [44/200], Step [400/937], d_loss: 0.3989, g_loss:2.41, D(G(z)): 0.96
# Epoch [44/200], Step [600/937], d_loss: 0.2260, g_loss:2.17, D(G(z)): 0.84
# Epoch [44/200], Step [800/937], d_loss: 0.7963, g_loss:2.99, D(G(z)): 0.57
# Epoch [45/200], Step [200/937], d_loss: 0.5151, g_loss:3.78, D(G(z)): 0.99
# Epoch [45/200], Step [400/937], d_loss: 0.1924, g_loss:2.65, D(G(z)): 0.88
# Epoch [45/200], Step [600/937], d_loss: 0.5002, g_loss:3.44, D(G(z)): 0.84
# Epoch [45/200], Step [800/937], d_loss: 0.1438, g_loss:5.12, D(G(z)): 0.94
# Epoch [46/200], Step [200/937], d_loss: 0.1954, g_loss:3.67, D(G(z)): 0.95
# Epoch [46/200], Step [400/937], d_loss: 0.2137, g_loss:2.81, D(G(z)): 0.84
# Epoch [46/200], Step [600/937], d_loss: 0.0971, g_loss:2.84, D(G(z)): 0.97
# Epoch [46/200], Step [800/937], d_loss: 1.2600, g_loss:5.27, D(G(z)): 0.96
# Epoch [47/200], Step [200/937], d_loss: 0.5454, g_loss:1.35, D(G(z)): 0.63
# Epoch [47/200], Step [400/937], d_loss: 0.4666, g_loss:2.46, D(G(z)): 0.87
# Epoch [47/200], Step [600/937], d_loss: 0.1152, g_loss:3.69, D(G(z)): 0.96
# Epoch [47/200], Step [800/937], d_loss: 0.3096, g_loss:5.08, D(G(z)): 0.79
# Epoch [48/200], Step [200/937], d_loss: 0.2726, g_loss:1.56, D(G(z)): 0.87
# Epoch [48/200], Step [400/937], d_loss: 0.5680, g_loss:3.72, D(G(z)): 0.84
# Epoch [48/200], Step [600/937], d_loss: 0.4430, g_loss:2.17, D(G(z)): 0.98
# Epoch [48/200], Step [800/937], d_loss: 0.0961, g_loss:3.25, D(G(z)): 0.94
# Epoch [49/200], Step [200/937], d_loss: 0.3239, g_loss:3.99, D(G(z)): 0.91
# Epoch [49/200], Step [400/937], d_loss: 0.2182, g_loss:2.53, D(G(z)): 0.90
# Epoch [49/200], Step [600/937], d_loss: 0.3455, g_loss:1.50, D(G(z)): 0.74
# Epoch [49/200], Step [800/937], d_loss: 0.6062, g_loss:3.77, D(G(z)): 0.97
# Epoch [50/200], Step [200/937], d_loss: 0.0897, g_loss:2.36, D(G(z)): 0.99
# Epoch [50/200], Step [400/937], d_loss: 0.1569, g_loss:0.51, D(G(z)): 0.95
# Epoch [50/200], Step [600/937], d_loss: 0.4409, g_loss:2.85, D(G(z)): 0.97
# Epoch [50/200], Step [800/937], d_loss: 0.2284, g_loss:4.17, D(G(z)): 0.96
# Epoch [51/200], Step [200/937], d_loss: 0.0898, g_loss:4.34, D(G(z)): 0.97
# Epoch [51/200], Step [400/937], d_loss: 0.0799, g_loss:4.12, D(G(z)): 0.96
# Epoch [51/200], Step [600/937], d_loss: 0.2182, g_loss:2.57, D(G(z)): 0.92
# Epoch [51/200], Step [800/937], d_loss: 0.4650, g_loss:2.44, D(G(z)): 0.96
# Epoch [52/200], Step [200/937], d_loss: 0.1538, g_loss:4.74, D(G(z)): 0.99
# Epoch [52/200], Step [400/937], d_loss: 0.7374, g_loss:4.32, D(G(z)): 0.93
# Epoch [52/200], Step [600/937], d_loss: 0.6299, g_loss:2.81, D(G(z)): 0.89
# Epoch [52/200], Step [800/937], d_loss: 0.3132, g_loss:1.84, D(G(z)): 0.94
# Epoch [53/200], Step [200/937], d_loss: 0.0585, g_loss:3.17, D(G(z)): 0.96
# Epoch [53/200], Step [400/937], d_loss: 0.3328, g_loss:2.67, D(G(z)): 0.94
# Epoch [53/200], Step [600/937], d_loss: 0.1002, g_loss:3.01, D(G(z)): 0.97
# Epoch [53/200], Step [800/937], d_loss: 0.1332, g_loss:1.67, D(G(z)): 0.96
# Epoch [54/200], Step [200/937], d_loss: 0.0876, g_loss:1.57, D(G(z)): 0.99
# Epoch [54/200], Step [400/937], d_loss: 0.9142, g_loss:2.37, D(G(z)): 0.96
# Epoch [54/200], Step [600/937], d_loss: 0.4799, g_loss:4.32, D(G(z)): 0.88
# Epoch [54/200], Step [800/937], d_loss: 0.3720, g_loss:3.96, D(G(z)): 0.96
# Epoch [55/200], Step [200/937], d_loss: 0.3065, g_loss:2.91, D(G(z)): 0.83
# Epoch [55/200], Step [400/937], d_loss: 0.1530, g_loss:3.11, D(G(z)): 0.99
# Epoch [55/200], Step [600/937], d_loss: 0.3681, g_loss:1.56, D(G(z)): 0.92
# Epoch [55/200], Step [800/937], d_loss: 0.0863, g_loss:4.33, D(G(z)): 0.96
# Epoch [56/200], Step [200/937], d_loss: 0.2002, g_loss:2.70, D(G(z)): 0.99
# Epoch [56/200], Step [400/937], d_loss: 0.2169, g_loss:3.72, D(G(z)): 0.84
# Epoch [56/200], Step [600/937], d_loss: 0.1877, g_loss:4.50, D(G(z)): 0.96
# Epoch [56/200], Step [800/937], d_loss: 0.1102, g_loss:2.92, D(G(z)): 0.95
# Epoch [57/200], Step [200/937], d_loss: 0.4326, g_loss:3.01, D(G(z)): 0.78
# Epoch [57/200], Step [400/937], d_loss: 0.1715, g_loss:2.97, D(G(z)): 0.96
# Epoch [57/200], Step [600/937], d_loss: 0.8025, g_loss:2.08, D(G(z)): 0.53
# Epoch [57/200], Step [800/937], d_loss: 0.5527, g_loss:4.33, D(G(z)): 0.67
# Epoch [58/200], Step [200/937], d_loss: 0.6614, g_loss:3.83, D(G(z)): 0.99
# Epoch [58/200], Step [400/937], d_loss: 0.3076, g_loss:1.57, D(G(z)): 0.91
# Epoch [58/200], Step [600/937], d_loss: 0.3533, g_loss:3.50, D(G(z)): 0.78
# Epoch [58/200], Step [800/937], d_loss: 0.2120, g_loss:1.85, D(G(z)): 0.98
# Epoch [59/200], Step [200/937], d_loss: 0.3131, g_loss:3.15, D(G(z)): 0.98
# Epoch [59/200], Step [400/937], d_loss: 0.1647, g_loss:3.49, D(G(z)): 0.86
# Epoch [59/200], Step [600/937], d_loss: 0.4426, g_loss:3.06, D(G(z)): 0.70
# Epoch [59/200], Step [800/937], d_loss: 0.4343, g_loss:2.63, D(G(z)): 0.74
# Epoch [60/200], Step [200/937], d_loss: 0.1946, g_loss:2.29, D(G(z)): 0.85
# Epoch [60/200], Step [400/937], d_loss: 0.2813, g_loss:5.03, D(G(z)): 0.90
# Epoch [60/200], Step [600/937], d_loss: 0.5705, g_loss:4.76, D(G(z)): 0.89
# Epoch [60/200], Step [800/937], d_loss: 0.5463, g_loss:4.42, D(G(z)): 0.90
# Epoch [61/200], Step [200/937], d_loss: 0.2133, g_loss:1.49, D(G(z)): 0.99
# Epoch [61/200], Step [400/937], d_loss: 0.7882, g_loss:2.83, D(G(z)): 0.56
# Epoch [61/200], Step [600/937], d_loss: 0.1221, g_loss:3.87, D(G(z)): 0.96
# Epoch [61/200], Step [800/937], d_loss: 0.1445, g_loss:2.26, D(G(z)): 0.90
# Epoch [62/200], Step [200/937], d_loss: 0.1464, g_loss:2.09, D(G(z)): 0.96
# Epoch [62/200], Step [400/937], d_loss: 0.2722, g_loss:2.15, D(G(z)): 0.98
# Epoch [62/200], Step [600/937], d_loss: 0.3163, g_loss:3.25, D(G(z)): 0.98
# Epoch [62/200], Step [800/937], d_loss: 0.1590, g_loss:4.30, D(G(z)): 0.93
# Epoch [63/200], Step [200/937], d_loss: 0.6356, g_loss:2.40, D(G(z)): 0.75
# Epoch [63/200], Step [400/937], d_loss: 0.1462, g_loss:3.63, D(G(z)): 0.98
# Epoch [63/200], Step [600/937], d_loss: 0.0748, g_loss:2.50, D(G(z)): 0.97
# Epoch [63/200], Step [800/937], d_loss: 0.2068, g_loss:3.42, D(G(z)): 0.96
# Epoch [64/200], Step [200/937], d_loss: 0.1259, g_loss:5.43, D(G(z)): 0.94
# Epoch [64/200], Step [400/937], d_loss: 0.3477, g_loss:5.17, D(G(z)): 0.84
# Epoch [64/200], Step [600/937], d_loss: 0.2783, g_loss:2.71, D(G(z)): 0.93
# Epoch [64/200], Step [800/937], d_loss: 0.2731, g_loss:1.29, D(G(z)): 0.97
# Epoch [65/200], Step [200/937], d_loss: 0.1742, g_loss:4.20, D(G(z)): 0.88
# Epoch [65/200], Step [400/937], d_loss: 0.2614, g_loss:1.58, D(G(z)): 0.91
# Epoch [65/200], Step [600/937], d_loss: 0.2880, g_loss:5.17, D(G(z)): 0.92
# Epoch [65/200], Step [800/937], d_loss: 0.2753, g_loss:4.66, D(G(z)): 0.95
# Epoch [66/200], Step [200/937], d_loss: 0.1687, g_loss:2.52, D(G(z)): 0.88
# Epoch [66/200], Step [400/937], d_loss: 0.2356, g_loss:3.31, D(G(z)): 0.88
# Epoch [66/200], Step [600/937], d_loss: 0.1249, g_loss:4.38, D(G(z)): 0.98
# Epoch [66/200], Step [800/937], d_loss: 0.2603, g_loss:2.80, D(G(z)): 0.85
# Epoch [67/200], Step [200/937], d_loss: 0.2023, g_loss:2.95, D(G(z)): 0.84
# Epoch [67/200], Step [400/937], d_loss: 0.1959, g_loss:4.18, D(G(z)): 0.87
# Epoch [67/200], Step [600/937], d_loss: 0.7047, g_loss:3.69, D(G(z)): 0.64
# Epoch [67/200], Step [800/937], d_loss: 0.6873, g_loss:4.52, D(G(z)): 0.71
# Epoch [68/200], Step [200/937], d_loss: 0.2723, g_loss:2.05, D(G(z)): 0.97
# Epoch [68/200], Step [400/937], d_loss: 0.0738, g_loss:3.59, D(G(z)): 0.96
# Epoch [68/200], Step [600/937], d_loss: 0.2606, g_loss:3.68, D(G(z)): 0.99
# Epoch [68/200], Step [800/937], d_loss: 0.5158, g_loss:2.22, D(G(z)): 0.66
# Epoch [69/200], Step [200/937], d_loss: 0.0596, g_loss:6.72, D(G(z)): 0.99
# Epoch [69/200], Step [400/937], d_loss: 0.6358, g_loss:3.10, D(G(z)): 0.70
# Epoch [69/200], Step [600/937], d_loss: 0.0784, g_loss:1.98, D(G(z)): 0.96
# Epoch [69/200], Step [800/937], d_loss: 0.1429, g_loss:3.84, D(G(z)): 0.95
# Epoch [70/200], Step [200/937], d_loss: 0.2893, g_loss:4.70, D(G(z)): 0.83
# Epoch [70/200], Step [400/937], d_loss: 1.6982, g_loss:4.99, D(G(z)): 0.97
# Epoch [70/200], Step [600/937], d_loss: 0.5354, g_loss:2.50, D(G(z)): 0.65
# Epoch [70/200], Step [800/937], d_loss: 0.2679, g_loss:1.60, D(G(z)): 0.99
# Epoch [71/200], Step [200/937], d_loss: 0.2971, g_loss:2.90, D(G(z)): 0.93
# Epoch [71/200], Step [400/937], d_loss: 1.1290, g_loss:1.23, D(G(z)): 0.39
# Epoch [71/200], Step [600/937], d_loss: 0.5240, g_loss:2.30, D(G(z)): 0.65
# Epoch [71/200], Step [800/937], d_loss: 0.1727, g_loss:3.57, D(G(z)): 0.90
# Epoch [72/200], Step [200/937], d_loss: 0.3972, g_loss:3.32, D(G(z)): 0.87
# Epoch [72/200], Step [400/937], d_loss: 0.5691, g_loss:3.13, D(G(z)): 0.68
# Epoch [72/200], Step [600/937], d_loss: 0.3415, g_loss:4.02, D(G(z)): 0.99
# Epoch [72/200], Step [800/937], d_loss: 0.1855, g_loss:5.12, D(G(z)): 0.94
# Epoch [73/200], Step [200/937], d_loss: 0.1011, g_loss:5.87, D(G(z)): 0.91
# Epoch [73/200], Step [400/937], d_loss: 0.2220, g_loss:1.38, D(G(z)): 0.96
# Epoch [73/200], Step [600/937], d_loss: 0.1384, g_loss:3.96, D(G(z)): 0.93
# Epoch [73/200], Step [800/937], d_loss: 0.5691, g_loss:4.51, D(G(z)): 0.98
# Epoch [74/200], Step [200/937], d_loss: 0.1387, g_loss:3.84, D(G(z)): 0.95
# Epoch [74/200], Step [400/937], d_loss: 0.2777, g_loss:2.21, D(G(z)): 0.89
# Epoch [74/200], Step [600/937], d_loss: 0.0993, g_loss:4.45, D(G(z)): 0.95
# Epoch [74/200], Step [800/937], d_loss: 0.2972, g_loss:2.88, D(G(z)): 0.95
# Epoch [75/200], Step [200/937], d_loss: 0.1661, g_loss:5.03, D(G(z)): 0.98
# Epoch [75/200], Step [400/937], d_loss: 0.1309, g_loss:3.52, D(G(z)): 0.89
# Epoch [75/200], Step [600/937], d_loss: 0.2571, g_loss:1.44, D(G(z)): 0.82
# Epoch [75/200], Step [800/937], d_loss: 0.2460, g_loss:3.10, D(G(z)): 0.99
# Epoch [76/200], Step [200/937], d_loss: 0.0944, g_loss:3.43, D(G(z)): 0.97
# Epoch [76/200], Step [400/937], d_loss: 0.2037, g_loss:3.35, D(G(z)): 0.97
# Epoch [76/200], Step [600/937], d_loss: 0.3813, g_loss:2.14, D(G(z)): 0.77
# Epoch [76/200], Step [800/937], d_loss: 0.4410, g_loss:1.62, D(G(z)): 0.88
# Epoch [77/200], Step [200/937], d_loss: 0.1755, g_loss:4.42, D(G(z)): 0.95
# Epoch [77/200], Step [400/937], d_loss: 0.1042, g_loss:3.27, D(G(z)): 0.95
# Epoch [77/200], Step [600/937], d_loss: 0.2268, g_loss:2.03, D(G(z)): 0.83
# Epoch [77/200], Step [800/937], d_loss: 0.1440, g_loss:2.68, D(G(z)): 0.96
# Epoch [78/200], Step [200/937], d_loss: 0.2228, g_loss:6.67, D(G(z)): 0.85
# Epoch [78/200], Step [400/937], d_loss: 0.3235, g_loss:1.66, D(G(z)): 0.99
# Epoch [78/200], Step [600/937], d_loss: 0.2960, g_loss:2.68, D(G(z)): 0.92
# Epoch [78/200], Step [800/937], d_loss: 0.0881, g_loss:5.13, D(G(z)): 0.93
# Epoch [79/200], Step [200/937], d_loss: 0.5273, g_loss:4.80, D(G(z)): 0.99
# Epoch [79/200], Step [400/937], d_loss: 0.7363, g_loss:6.75, D(G(z)): 0.99
# Epoch [79/200], Step [600/937], d_loss: 0.2650, g_loss:2.87, D(G(z)): 0.80
# Epoch [79/200], Step [800/937], d_loss: 0.1522, g_loss:3.12, D(G(z)): 0.97
# Epoch [80/200], Step [200/937], d_loss: 0.1690, g_loss:3.51, D(G(z)): 0.91
# Epoch [80/200], Step [400/937], d_loss: 0.3491, g_loss:2.73, D(G(z)): 0.74
# Epoch [80/200], Step [600/937], d_loss: 0.0809, g_loss:3.40, D(G(z)): 0.97
# Epoch [80/200], Step [800/937], d_loss: 0.4523, g_loss:5.50, D(G(z)): 0.86
# Epoch [81/200], Step [200/937], d_loss: 1.0359, g_loss:3.14, D(G(z)): 0.61
# Epoch [81/200], Step [400/937], d_loss: 0.3738, g_loss:1.29, D(G(z)): 0.99
# Epoch [81/200], Step [600/937], d_loss: 0.2953, g_loss:4.15, D(G(z)): 0.86
# Epoch [81/200], Step [800/937], d_loss: 0.0916, g_loss:4.69, D(G(z)): 0.98
# Epoch [82/200], Step [200/937], d_loss: 0.0677, g_loss:2.42, D(G(z)): 0.94
# Epoch [82/200], Step [400/937], d_loss: 0.1014, g_loss:2.71, D(G(z)): 0.93
# Epoch [82/200], Step [600/937], d_loss: 0.1526, g_loss:1.73, D(G(z)): 0.92
# Epoch [82/200], Step [800/937], d_loss: 0.2671, g_loss:3.82, D(G(z)): 0.98
# Epoch [83/200], Step [200/937], d_loss: 0.0902, g_loss:3.95, D(G(z)): 0.97
# Epoch [83/200], Step [400/937], d_loss: 0.1436, g_loss:5.37, D(G(z)): 0.97
# Epoch [83/200], Step [600/937], d_loss: 0.2091, g_loss:4.10, D(G(z)): 0.88
# Epoch [83/200], Step [800/937], d_loss: 0.2348, g_loss:5.60, D(G(z)): 0.81
# Epoch [84/200], Step [200/937], d_loss: 0.1017, g_loss:4.67, D(G(z)): 0.99
# Epoch [84/200], Step [400/937], d_loss: 0.2101, g_loss:5.02, D(G(z)): 0.85
# Epoch [84/200], Step [600/937], d_loss: 0.2481, g_loss:0.85, D(G(z)): 0.98
# Epoch [84/200], Step [800/937], d_loss: 0.3090, g_loss:3.90, D(G(z)): 0.85
# Epoch [85/200], Step [200/937], d_loss: 0.0672, g_loss:3.39, D(G(z)): 0.99
# Epoch [85/200], Step [400/937], d_loss: 0.3984, g_loss:1.37, D(G(z)): 0.72
# Epoch [85/200], Step [600/937], d_loss: 0.2992, g_loss:3.96, D(G(z)): 0.86
# Epoch [85/200], Step [800/937], d_loss: 0.2792, g_loss:4.72, D(G(z)): 0.89
# Epoch [86/200], Step [200/937], d_loss: 0.2592, g_loss:1.77, D(G(z)): 0.95
# Epoch [86/200], Step [400/937], d_loss: 0.0865, g_loss:4.14, D(G(z)): 0.97
# Epoch [86/200], Step [600/937], d_loss: 0.2949, g_loss:4.24, D(G(z)): 0.97
# Epoch [86/200], Step [800/937], d_loss: 0.2470, g_loss:5.22, D(G(z)): 0.95
# Epoch [87/200], Step [200/937], d_loss: 0.0547, g_loss:3.84, D(G(z)): 0.97
# Epoch [87/200], Step [400/937], d_loss: 0.1030, g_loss:4.06, D(G(z)): 0.94
# Epoch [87/200], Step [600/937], d_loss: 0.3811, g_loss:4.16, D(G(z)): 0.99
# Epoch [87/200], Step [800/937], d_loss: 0.0852, g_loss:2.33, D(G(z)): 0.94
# Epoch [88/200], Step [200/937], d_loss: 0.9306, g_loss:1.87, D(G(z)): 0.55
# Epoch [88/200], Step [400/937], d_loss: 0.1799, g_loss:2.93, D(G(z)): 0.85
# Epoch [88/200], Step [600/937], d_loss: 0.3636, g_loss:3.85, D(G(z)): 0.77
# Epoch [88/200], Step [800/937], d_loss: 0.8476, g_loss:1.57, D(G(z)): 0.52
# Epoch [89/200], Step [200/937], d_loss: 1.1362, g_loss:1.97, D(G(z)): 1.00
# Epoch [89/200], Step [400/937], d_loss: 0.4212, g_loss:3.37, D(G(z)): 0.86
# Epoch [89/200], Step [600/937], d_loss: 0.2687, g_loss:5.11, D(G(z)): 0.92
# Epoch [89/200], Step [800/937], d_loss: 0.2345, g_loss:1.59, D(G(z)): 0.99
# Epoch [90/200], Step [200/937], d_loss: 0.2291, g_loss:3.95, D(G(z)): 0.87
# Epoch [90/200], Step [400/937], d_loss: 0.2166, g_loss:1.58, D(G(z)): 0.85
# Epoch [90/200], Step [600/937], d_loss: 0.1014, g_loss:3.77, D(G(z)): 0.99
# Epoch [90/200], Step [800/937], d_loss: 0.0922, g_loss:5.46, D(G(z)): 0.94
# Epoch [91/200], Step [200/937], d_loss: 0.1743, g_loss:3.82, D(G(z)): 0.88
# Epoch [91/200], Step [400/937], d_loss: 0.2646, g_loss:3.40, D(G(z)): 0.94
# Epoch [91/200], Step [600/937], d_loss: 0.0366, g_loss:4.65, D(G(z)): 0.98
# Epoch [91/200], Step [800/937], d_loss: 0.0945, g_loss:1.95, D(G(z)): 0.98
# Epoch [92/200], Step [200/937], d_loss: 0.4718, g_loss:2.27, D(G(z)): 0.77
# Epoch [92/200], Step [400/937], d_loss: 0.3864, g_loss:1.90, D(G(z)): 0.80
# Epoch [92/200], Step [600/937], d_loss: 0.1448, g_loss:3.31, D(G(z)): 0.99
# Epoch [92/200], Step [800/937], d_loss: 0.3424, g_loss:2.93, D(G(z)): 0.91
# Epoch [93/200], Step [200/937], d_loss: 0.1790, g_loss:4.70, D(G(z)): 0.99
# Epoch [93/200], Step [400/937], d_loss: 0.1036, g_loss:5.09, D(G(z)): 0.97
# Epoch [93/200], Step [600/937], d_loss: 0.2418, g_loss:3.03, D(G(z)): 0.90
# Epoch [93/200], Step [800/937], d_loss: 0.1514, g_loss:1.66, D(G(z)): 0.95
# Epoch [94/200], Step [200/937], d_loss: 0.1178, g_loss:4.79, D(G(z)): 0.91
# Epoch [94/200], Step [400/937], d_loss: 0.3269, g_loss:3.14, D(G(z)): 0.91
# Epoch [94/200], Step [600/937], d_loss: 0.1077, g_loss:4.27, D(G(z)): 0.91
# Epoch [94/200], Step [800/937], d_loss: 0.1503, g_loss:2.00, D(G(z)): 0.98
# Epoch [95/200], Step [200/937], d_loss: 0.1003, g_loss:0.91, D(G(z)): 0.96
# Epoch [95/200], Step [400/937], d_loss: 0.3887, g_loss:3.53, D(G(z)): 0.95
# Epoch [95/200], Step [600/937], d_loss: 0.1688, g_loss:6.37, D(G(z)): 0.98
# Epoch [95/200], Step [800/937], d_loss: 0.3245, g_loss:5.04, D(G(z)): 0.88
# Epoch [96/200], Step [200/937], d_loss: 0.1899, g_loss:2.54, D(G(z)): 0.88
# Epoch [96/200], Step [400/937], d_loss: 0.1184, g_loss:2.83, D(G(z)): 0.97
# Epoch [96/200], Step [600/937], d_loss: 0.8374, g_loss:5.13, D(G(z)): 0.99
# Epoch [96/200], Step [800/937], d_loss: 0.0844, g_loss:2.19, D(G(z)): 0.95
# Epoch [97/200], Step [200/937], d_loss: 0.1023, g_loss:3.95, D(G(z)): 0.97
# Epoch [97/200], Step [400/937], d_loss: 0.3479, g_loss:5.87, D(G(z)): 0.93
# Epoch [97/200], Step [600/937], d_loss: 0.0784, g_loss:5.62, D(G(z)): 0.98
# Epoch [97/200], Step [800/937], d_loss: 0.1617, g_loss:3.27, D(G(z)): 0.87
# Epoch [98/200], Step [200/937], d_loss: 0.3176, g_loss:3.12, D(G(z)): 0.93
# Epoch [98/200], Step [400/937], d_loss: 0.0803, g_loss:1.57, D(G(z)): 0.96
# Epoch [98/200], Step [600/937], d_loss: 0.2653, g_loss:4.32, D(G(z)): 0.82
# Epoch [98/200], Step [800/937], d_loss: 0.4727, g_loss:1.73, D(G(z)): 0.67
# Epoch [99/200], Step [200/937], d_loss: 0.6076, g_loss:3.05, D(G(z)): 0.63
# Epoch [99/200], Step [400/937], d_loss: 0.0653, g_loss:3.32, D(G(z)): 0.98
# Epoch [99/200], Step [600/937], d_loss: 0.0237, g_loss:2.24, D(G(z)): 1.00
# Epoch [99/200], Step [800/937], d_loss: 0.6473, g_loss:4.76, D(G(z)): 0.70
# Epoch [100/200], Step [200/937], d_loss: 0.2043, g_loss:2.75, D(G(z)): 0.98
# Epoch [100/200], Step [400/937], d_loss: 0.1187, g_loss:4.38, D(G(z)): 0.91
# Epoch [100/200], Step [600/937], d_loss: 0.2362, g_loss:1.48, D(G(z)): 0.91
# Epoch [100/200], Step [800/937], d_loss: 0.4254, g_loss:1.91, D(G(z)): 0.76
# Epoch [101/200], Step [200/937], d_loss: 0.1481, g_loss:1.39, D(G(z)): 0.95
# Epoch [101/200], Step [400/937], d_loss: 0.0272, g_loss:4.92, D(G(z)): 0.98
# Epoch [101/200], Step [600/937], d_loss: 0.3538, g_loss:2.34, D(G(z)): 0.99
# Epoch [101/200], Step [800/937], d_loss: 0.0522, g_loss:2.71, D(G(z)): 0.97
# Epoch [102/200], Step [200/937], d_loss: 0.0787, g_loss:3.51, D(G(z)): 0.99
# Epoch [102/200], Step [400/937], d_loss: 0.2296, g_loss:2.55, D(G(z)): 1.00
# Epoch [102/200], Step [600/937], d_loss: 0.1337, g_loss:4.40, D(G(z)): 0.95
# Epoch [102/200], Step [800/937], d_loss: 0.0487, g_loss:3.60, D(G(z)): 0.96
# Epoch [103/200], Step [200/937], d_loss: 0.6805, g_loss:4.07, D(G(z)): 0.83
# Epoch [103/200], Step [400/937], d_loss: 0.1455, g_loss:3.43, D(G(z)): 0.96
# Epoch [103/200], Step [600/937], d_loss: 0.4544, g_loss:5.73, D(G(z)): 0.89
# Epoch [103/200], Step [800/937], d_loss: 0.1195, g_loss:2.55, D(G(z)): 0.94
# Epoch [104/200], Step [200/937], d_loss: 0.0712, g_loss:1.55, D(G(z)): 0.99
# Epoch [104/200], Step [400/937], d_loss: 0.1682, g_loss:3.69, D(G(z)): 0.94
# Epoch [104/200], Step [600/937], d_loss: 0.1769, g_loss:2.06, D(G(z)): 0.93
# Epoch [104/200], Step [800/937], d_loss: 0.2948, g_loss:4.88, D(G(z)): 0.95
# Epoch [105/200], Step [200/937], d_loss: 0.5260, g_loss:2.62, D(G(z)): 0.68
# Epoch [105/200], Step [400/937], d_loss: 0.1856, g_loss:5.51, D(G(z)): 0.90
# Epoch [105/200], Step [600/937], d_loss: 0.0427, g_loss:2.60, D(G(z)): 0.98
# Epoch [105/200], Step [800/937], d_loss: 0.2889, g_loss:6.17, D(G(z)): 0.80
# Epoch [106/200], Step [200/937], d_loss: 1.0102, g_loss:2.42, D(G(z)): 0.45
# Epoch [106/200], Step [400/937], d_loss: 0.3216, g_loss:2.44, D(G(z)): 0.91
# Epoch [106/200], Step [600/937], d_loss: 0.1244, g_loss:2.04, D(G(z)): 0.94
# Epoch [106/200], Step [800/937], d_loss: 0.0391, g_loss:4.06, D(G(z)): 0.99
# Epoch [107/200], Step [200/937], d_loss: 0.0284, g_loss:4.46, D(G(z)): 0.99
# Epoch [107/200], Step [400/937], d_loss: 0.2857, g_loss:0.84, D(G(z)): 1.00
# Epoch [107/200], Step [600/937], d_loss: 0.5859, g_loss:2.34, D(G(z)): 0.64
# Epoch [107/200], Step [800/937], d_loss: 0.2554, g_loss:2.96, D(G(z)): 0.80
# Epoch [108/200], Step [200/937], d_loss: 1.3956, g_loss:3.13, D(G(z)): 0.77
# Epoch [108/200], Step [400/937], d_loss: 0.0794, g_loss:1.89, D(G(z)): 0.97
# Epoch [108/200], Step [600/937], d_loss: 0.5770, g_loss:3.64, D(G(z)): 0.98
# Epoch [108/200], Step [800/937], d_loss: 0.0744, g_loss:2.82, D(G(z)): 0.99
# Epoch [109/200], Step [200/937], d_loss: 0.0893, g_loss:5.29, D(G(z)): 0.94
# Epoch [109/200], Step [400/937], d_loss: 0.6088, g_loss:2.21, D(G(z)): 0.65
# Epoch [109/200], Step [600/937], d_loss: 0.2159, g_loss:6.84, D(G(z)): 0.82
# Epoch [109/200], Step [800/937], d_loss: 0.0513, g_loss:1.47, D(G(z)): 0.99
# Epoch [110/200], Step [200/937], d_loss: 0.1444, g_loss:3.83, D(G(z)): 0.91
# Epoch [110/200], Step [400/937], d_loss: 0.3338, g_loss:1.82, D(G(z)): 0.79
# Epoch [110/200], Step [600/937], d_loss: 0.0250, g_loss:0.91, D(G(z)): 1.00
# Epoch [110/200], Step [800/937], d_loss: 0.1905, g_loss:3.78, D(G(z)): 0.94
# Epoch [111/200], Step [200/937], d_loss: 0.4336, g_loss:1.96, D(G(z)): 0.73
# Epoch [111/200], Step [400/937], d_loss: 0.1015, g_loss:4.18, D(G(z)): 0.99
# Epoch [111/200], Step [600/937], d_loss: 0.6363, g_loss:3.37, D(G(z)): 0.57
# Epoch [111/200], Step [800/937], d_loss: 0.5388, g_loss:5.30, D(G(z)): 0.67
# Epoch [112/200], Step [200/937], d_loss: 0.6934, g_loss:3.44, D(G(z)): 0.98
# Epoch [112/200], Step [400/937], d_loss: 0.2016, g_loss:4.35, D(G(z)): 0.86
# Epoch [112/200], Step [600/937], d_loss: 0.0635, g_loss:1.20, D(G(z)): 0.98
# Epoch [112/200], Step [800/937], d_loss: 0.1185, g_loss:2.84, D(G(z)): 0.97
# Epoch [113/200], Step [200/937], d_loss: 0.9139, g_loss:1.27, D(G(z)): 0.99
# Epoch [113/200], Step [400/937], d_loss: 0.3390, g_loss:4.73, D(G(z)): 0.94
# Epoch [113/200], Step [600/937], d_loss: 0.1986, g_loss:5.20, D(G(z)): 0.95
# Epoch [113/200], Step [800/937], d_loss: 0.3059, g_loss:1.96, D(G(z)): 0.79
# Epoch [114/200], Step [200/937], d_loss: 0.6232, g_loss:2.86, D(G(z)): 0.88
# Epoch [114/200], Step [400/937], d_loss: 0.0813, g_loss:2.65, D(G(z)): 0.94
# Epoch [114/200], Step [600/937], d_loss: 0.1217, g_loss:4.40, D(G(z)): 0.92
# Epoch [114/200], Step [800/937], d_loss: 0.5757, g_loss:2.91, D(G(z)): 0.92
# Epoch [115/200], Step [200/937], d_loss: 0.1060, g_loss:4.99, D(G(z)): 0.92
# Epoch [115/200], Step [400/937], d_loss: 0.0894, g_loss:3.65, D(G(z)): 0.97
# Epoch [115/200], Step [600/937], d_loss: 0.1823, g_loss:3.71, D(G(z)): 0.88
# Epoch [115/200], Step [800/937], d_loss: 0.0879, g_loss:0.95, D(G(z)): 0.98
# Epoch [116/200], Step [200/937], d_loss: 0.1734, g_loss:2.52, D(G(z)): 0.87
# Epoch [116/200], Step [400/937], d_loss: 0.3037, g_loss:0.62, D(G(z)): 0.98
# Epoch [116/200], Step [600/937], d_loss: 0.2069, g_loss:2.67, D(G(z)): 0.98
# Epoch [116/200], Step [800/937], d_loss: 0.0985, g_loss:4.01, D(G(z)): 0.96
# Epoch [117/200], Step [200/937], d_loss: 0.2669, g_loss:2.27, D(G(z)): 0.98
# Epoch [117/200], Step [400/937], d_loss: 0.2765, g_loss:4.31, D(G(z)): 0.80
# Epoch [117/200], Step [600/937], d_loss: 0.1272, g_loss:1.92, D(G(z)): 1.00
# Epoch [117/200], Step [800/937], d_loss: 0.0561, g_loss:1.70, D(G(z)): 0.97
# Epoch [118/200], Step [200/937], d_loss: 0.0456, g_loss:3.44, D(G(z)): 0.97
# Epoch [118/200], Step [400/937], d_loss: 1.5262, g_loss:5.03, D(G(z)): 0.89
# Epoch [118/200], Step [600/937], d_loss: 0.1364, g_loss:3.57, D(G(z)): 0.91
# Epoch [118/200], Step [800/937], d_loss: 0.5440, g_loss:3.21, D(G(z)): 0.94
# Epoch [119/200], Step [200/937], d_loss: 1.1490, g_loss:6.04, D(G(z)): 0.92
# Epoch [119/200], Step [400/937], d_loss: 0.4704, g_loss:4.22, D(G(z)): 0.81
# Epoch [119/200], Step [600/937], d_loss: 0.3256, g_loss:4.97, D(G(z)): 0.74
# Epoch [119/200], Step [800/937], d_loss: 0.1508, g_loss:2.44, D(G(z)): 0.91
# Epoch [120/200], Step [200/937], d_loss: 0.3294, g_loss:4.21, D(G(z)): 0.95
# Epoch [120/200], Step [400/937], d_loss: 1.4252, g_loss:4.32, D(G(z)): 0.33
# Epoch [120/200], Step [600/937], d_loss: 0.1248, g_loss:3.44, D(G(z)): 0.92
# Epoch [120/200], Step [800/937], d_loss: 0.1661, g_loss:3.90, D(G(z)): 0.99
# Epoch [121/200], Step [200/937], d_loss: 0.4373, g_loss:2.82, D(G(z)): 0.98
# Epoch [121/200], Step [400/937], d_loss: 0.5457, g_loss:2.17, D(G(z)): 1.00
# Epoch [121/200], Step [600/937], d_loss: 0.4164, g_loss:6.61, D(G(z)): 0.73
# Epoch [121/200], Step [800/937], d_loss: 0.1410, g_loss:1.36, D(G(z)): 0.99
# Epoch [122/200], Step [200/937], d_loss: 0.1431, g_loss:4.79, D(G(z)): 0.88
# Epoch [122/200], Step [400/937], d_loss: 0.0858, g_loss:3.59, D(G(z)): 0.95
# Epoch [122/200], Step [600/937], d_loss: 0.4106, g_loss:3.99, D(G(z)): 0.94
# Epoch [122/200], Step [800/937], d_loss: 0.3686, g_loss:3.46, D(G(z)): 0.97
# Epoch [123/200], Step [200/937], d_loss: 0.4292, g_loss:2.59, D(G(z)): 0.70
# Epoch [123/200], Step [400/937], d_loss: 0.2606, g_loss:5.16, D(G(z)): 0.83
# Epoch [123/200], Step [600/937], d_loss: 0.2958, g_loss:5.36, D(G(z)): 0.89
# Epoch [123/200], Step [800/937], d_loss: 0.0836, g_loss:1.95, D(G(z)): 0.95
# Epoch [124/200], Step [200/937], d_loss: 0.8207, g_loss:3.46, D(G(z)): 0.54
# Epoch [124/200], Step [400/937], d_loss: 0.2121, g_loss:4.83, D(G(z)): 0.98
# Epoch [124/200], Step [600/937], d_loss: 0.1427, g_loss:3.17, D(G(z)): 0.89
# Epoch [124/200], Step [800/937], d_loss: 0.2522, g_loss:2.12, D(G(z)): 0.87
# Epoch [125/200], Step [200/937], d_loss: 0.2814, g_loss:3.59, D(G(z)): 0.98
# Epoch [125/200], Step [400/937], d_loss: 0.2015, g_loss:1.81, D(G(z)): 0.84
# Epoch [125/200], Step [600/937], d_loss: 0.2256, g_loss:2.17, D(G(z)): 0.86
# Epoch [125/200], Step [800/937], d_loss: 0.3596, g_loss:2.72, D(G(z)): 0.96
# Epoch [126/200], Step [200/937], d_loss: 0.0798, g_loss:1.92, D(G(z)): 0.99
# Epoch [126/200], Step [400/937], d_loss: 0.5837, g_loss:3.56, D(G(z)): 0.70
# Epoch [126/200], Step [600/937], d_loss: 0.3128, g_loss:2.47, D(G(z)): 0.99
# Epoch [126/200], Step [800/937], d_loss: 0.1680, g_loss:3.61, D(G(z)): 0.95
# Epoch [127/200], Step [200/937], d_loss: 0.6341, g_loss:4.20, D(G(z)): 0.80
# Epoch [127/200], Step [400/937], d_loss: 0.1343, g_loss:1.38, D(G(z)): 0.93
# Epoch [127/200], Step [600/937], d_loss: 0.5169, g_loss:3.61, D(G(z)): 0.94
# Epoch [127/200], Step [800/937], d_loss: 0.0808, g_loss:4.62, D(G(z)): 0.99
# Epoch [128/200], Step [200/937], d_loss: 0.0151, g_loss:1.60, D(G(z)): 0.99
# Epoch [128/200], Step [400/937], d_loss: 0.0867, g_loss:4.99, D(G(z)): 0.97
# Epoch [128/200], Step [600/937], d_loss: 0.5057, g_loss:5.51, D(G(z)): 0.66
# Epoch [128/200], Step [800/937], d_loss: 0.4020, g_loss:1.79, D(G(z)): 0.82
# Epoch [129/200], Step [200/937], d_loss: 0.1023, g_loss:4.88, D(G(z)): 0.97
# Epoch [129/200], Step [400/937], d_loss: 0.1508, g_loss:2.08, D(G(z)): 0.96
# Epoch [129/200], Step [600/937], d_loss: 0.2153, g_loss:4.64, D(G(z)): 0.94
# Epoch [129/200], Step [800/937], d_loss: 0.1473, g_loss:3.81, D(G(z)): 0.96
# Epoch [130/200], Step [200/937], d_loss: 0.1272, g_loss:2.15, D(G(z)): 0.93
# Epoch [130/200], Step [400/937], d_loss: 0.0433, g_loss:3.62, D(G(z)): 0.96
# Epoch [130/200], Step [600/937], d_loss: 0.0978, g_loss:1.61, D(G(z)): 1.00
# Epoch [130/200], Step [800/937], d_loss: 0.3142, g_loss:3.21, D(G(z)): 0.92
# Epoch [131/200], Step [200/937], d_loss: 0.0423, g_loss:3.74, D(G(z)): 0.97
# Epoch [131/200], Step [400/937], d_loss: 0.1107, g_loss:2.43, D(G(z)): 0.91
# Epoch [131/200], Step [600/937], d_loss: 0.0601, g_loss:0.80, D(G(z)): 0.99
# Epoch [131/200], Step [800/937], d_loss: 0.2256, g_loss:4.87, D(G(z)): 0.94
# Epoch [132/200], Step [200/937], d_loss: 0.1119, g_loss:3.82, D(G(z)): 0.97
# Epoch [132/200], Step [400/937], d_loss: 0.7844, g_loss:4.37, D(G(z)): 0.93
# Epoch [132/200], Step [600/937], d_loss: 0.0665, g_loss:1.46, D(G(z)): 0.99
# Epoch [132/200], Step [800/937], d_loss: 0.1020, g_loss:2.45, D(G(z)): 0.97
# Epoch [133/200], Step [200/937], d_loss: 0.5378, g_loss:3.14, D(G(z)): 0.69
# Epoch [133/200], Step [400/937], d_loss: 0.0932, g_loss:3.25, D(G(z)): 0.99
# Epoch [133/200], Step [600/937], d_loss: 0.1540, g_loss:2.20, D(G(z)): 0.88
# Epoch [133/200], Step [800/937], d_loss: 0.1402, g_loss:4.31, D(G(z)): 0.94
# Epoch [134/200], Step [200/937], d_loss: 0.1301, g_loss:3.07, D(G(z)): 0.90
# Epoch [134/200], Step [400/937], d_loss: 0.4577, g_loss:1.91, D(G(z)): 0.99
# Epoch [134/200], Step [600/937], d_loss: 0.2043, g_loss:2.39, D(G(z)): 0.96
# Epoch [134/200], Step [800/937], d_loss: 0.2136, g_loss:2.84, D(G(z)): 0.83
# Epoch [135/200], Step [200/937], d_loss: 0.5279, g_loss:3.34, D(G(z)): 0.98
# Epoch [135/200], Step [400/937], d_loss: 1.0186, g_loss:2.26, D(G(z)): 0.44
# Epoch [135/200], Step [600/937], d_loss: 0.0987, g_loss:2.48, D(G(z)): 0.99
# Epoch [135/200], Step [800/937], d_loss: 1.1037, g_loss:3.07, D(G(z)): 0.53
# Epoch [136/200], Step [200/937], d_loss: 0.0549, g_loss:4.66, D(G(z)): 0.96
# Epoch [136/200], Step [400/937], d_loss: 0.1960, g_loss:2.32, D(G(z)): 0.93
# Epoch [136/200], Step [600/937], d_loss: 0.4235, g_loss:2.14, D(G(z)): 0.98
# Epoch [136/200], Step [800/937], d_loss: 0.1912, g_loss:3.36, D(G(z)): 0.99
# Epoch [137/200], Step [200/937], d_loss: 0.4976, g_loss:3.81, D(G(z)): 0.98
# Epoch [137/200], Step [400/937], d_loss: 0.3566, g_loss:4.06, D(G(z)): 0.94
# Epoch [137/200], Step [600/937], d_loss: 0.1523, g_loss:4.22, D(G(z)): 0.97
# Epoch [137/200], Step [800/937], d_loss: 0.5663, g_loss:3.14, D(G(z)): 0.62
# Epoch [138/200], Step [200/937], d_loss: 0.6896, g_loss:3.83, D(G(z)): 0.99
# Epoch [138/200], Step [400/937], d_loss: 0.2906, g_loss:0.89, D(G(z)): 0.88
# Epoch [138/200], Step [600/937], d_loss: 0.9930, g_loss:2.37, D(G(z)): 0.77
# Epoch [138/200], Step [800/937], d_loss: 0.0882, g_loss:4.49, D(G(z)): 0.92
# Epoch [139/200], Step [200/937], d_loss: 0.1629, g_loss:4.76, D(G(z)): 0.98
# Epoch [139/200], Step [400/937], d_loss: 0.1189, g_loss:2.30, D(G(z)): 0.99
# Epoch [139/200], Step [600/937], d_loss: 1.1152, g_loss:3.23, D(G(z)): 0.85
# Epoch [139/200], Step [800/937], d_loss: 0.1511, g_loss:2.46, D(G(z)): 0.90
# Epoch [140/200], Step [200/937], d_loss: 0.3191, g_loss:0.17, D(G(z)): 0.99
# Epoch [140/200], Step [400/937], d_loss: 0.0432, g_loss:4.34, D(G(z)): 0.98
# Epoch [140/200], Step [600/937], d_loss: 0.4573, g_loss:2.77, D(G(z)): 0.98
# Epoch [140/200], Step [800/937], d_loss: 0.0966, g_loss:3.65, D(G(z)): 0.99
# Epoch [141/200], Step [200/937], d_loss: 0.1604, g_loss:6.13, D(G(z)): 0.88
# Epoch [141/200], Step [400/937], d_loss: 0.2878, g_loss:3.71, D(G(z)): 0.84
# Epoch [141/200], Step [600/937], d_loss: 0.1815, g_loss:2.27, D(G(z)): 0.91
# Epoch [141/200], Step [800/937], d_loss: 0.1762, g_loss:3.43, D(G(z)): 0.91
# Epoch [142/200], Step [200/937], d_loss: 0.1203, g_loss:2.46, D(G(z)): 0.90
# Epoch [142/200], Step [400/937], d_loss: 0.3650, g_loss:2.80, D(G(z)): 0.75
# Epoch [142/200], Step [600/937], d_loss: 0.4510, g_loss:2.50, D(G(z)): 0.96
# Epoch [142/200], Step [800/937], d_loss: 0.1350, g_loss:2.68, D(G(z)): 0.97
# Epoch [143/200], Step [200/937], d_loss: 0.2328, g_loss:1.49, D(G(z)): 0.95
# Epoch [143/200], Step [400/937], d_loss: 0.2290, g_loss:3.07, D(G(z)): 0.84
# Epoch [143/200], Step [600/937], d_loss: 0.0611, g_loss:1.40, D(G(z)): 0.97
# Epoch [143/200], Step [800/937], d_loss: 0.1671, g_loss:2.56, D(G(z)): 0.96
# Epoch [144/200], Step [200/937], d_loss: 0.1413, g_loss:3.12, D(G(z)): 0.93
# Epoch [144/200], Step [400/937], d_loss: 0.4781, g_loss:4.46, D(G(z)): 0.99
# Epoch [144/200], Step [600/937], d_loss: 0.0924, g_loss:2.33, D(G(z)): 0.96
# Epoch [144/200], Step [800/937], d_loss: 1.6366, g_loss:0.49, D(G(z)): 0.26
# Epoch [145/200], Step [200/937], d_loss: 0.7849, g_loss:1.82, D(G(z)): 0.99
# Epoch [145/200], Step [400/937], d_loss: 0.3862, g_loss:3.02, D(G(z)): 0.91
# Epoch [145/200], Step [600/937], d_loss: 0.4911, g_loss:4.04, D(G(z)): 0.71
# Epoch [145/200], Step [800/937], d_loss: 0.4467, g_loss:0.53, D(G(z)): 0.88
# Epoch [146/200], Step [200/937], d_loss: 0.2311, g_loss:4.34, D(G(z)): 0.82
# Epoch [146/200], Step [400/937], d_loss: 0.0881, g_loss:5.52, D(G(z)): 0.98
# Epoch [146/200], Step [600/937], d_loss: 0.2678, g_loss:2.51, D(G(z)): 0.81
# Epoch [146/200], Step [800/937], d_loss: 0.0835, g_loss:5.55, D(G(z)): 0.98
# Epoch [147/200], Step [200/937], d_loss: 0.2374, g_loss:5.23, D(G(z)): 0.99
# Epoch [147/200], Step [400/937], d_loss: 0.0944, g_loss:4.48, D(G(z)): 0.94
# Epoch [147/200], Step [600/937], d_loss: 0.0934, g_loss:2.84, D(G(z)): 0.94
# Epoch [147/200], Step [800/937], d_loss: 0.3290, g_loss:4.29, D(G(z)): 0.78
# Epoch [148/200], Step [200/937], d_loss: 0.0814, g_loss:2.87, D(G(z)): 0.93
# Epoch [148/200], Step [400/937], d_loss: 0.2693, g_loss:4.46, D(G(z)): 0.81
# Epoch [148/200], Step [600/937], d_loss: 0.2492, g_loss:3.84, D(G(z)): 0.97
# Epoch [148/200], Step [800/937], d_loss: 0.4837, g_loss:1.30, D(G(z)): 1.00
# Epoch [149/200], Step [200/937], d_loss: 0.0767, g_loss:3.44, D(G(z)): 0.96
# Epoch [149/200], Step [400/937], d_loss: 0.0776, g_loss:1.73, D(G(z)): 0.97
# Epoch [149/200], Step [600/937], d_loss: 0.3175, g_loss:4.32, D(G(z)): 0.84
# Epoch [149/200], Step [800/937], d_loss: 0.1553, g_loss:3.73, D(G(z)): 0.87
# Epoch [150/200], Step [200/937], d_loss: 0.2622, g_loss:2.96, D(G(z)): 0.92
# Epoch [150/200], Step [400/937], d_loss: 0.0415, g_loss:2.86, D(G(z)): 0.97
# Epoch [150/200], Step [600/937], d_loss: 0.3470, g_loss:2.70, D(G(z)): 0.87
# Epoch [150/200], Step [800/937], d_loss: 0.0919, g_loss:4.00, D(G(z)): 0.99
# Epoch [151/200], Step [200/937], d_loss: 0.3355, g_loss:4.48, D(G(z)): 0.76
# Epoch [151/200], Step [400/937], d_loss: 0.3285, g_loss:6.71, D(G(z)): 0.79
# Epoch [151/200], Step [600/937], d_loss: 0.1933, g_loss:1.77, D(G(z)): 0.87
# Epoch [151/200], Step [800/937], d_loss: 0.9357, g_loss:5.14, D(G(z)): 0.57
# Epoch [152/200], Step [200/937], d_loss: 0.6395, g_loss:3.66, D(G(z)): 0.64
# Epoch [152/200], Step [400/937], d_loss: 1.1559, g_loss:4.62, D(G(z)): 0.48
# Epoch [152/200], Step [600/937], d_loss: 1.3276, g_loss:2.98, D(G(z)): 0.98
# Epoch [152/200], Step [800/937], d_loss: 0.1768, g_loss:5.19, D(G(z)): 0.86
# Epoch [153/200], Step [200/937], d_loss: 0.0354, g_loss:0.99, D(G(z)): 0.99
# Epoch [153/200], Step [400/937], d_loss: 0.1394, g_loss:1.51, D(G(z)): 0.89
# Epoch [153/200], Step [600/937], d_loss: 0.9082, g_loss:2.36, D(G(z)): 0.65
# Epoch [153/200], Step [800/937], d_loss: 0.2267, g_loss:2.22, D(G(z)): 0.91
# Epoch [154/200], Step [200/937], d_loss: 0.0717, g_loss:2.25, D(G(z)): 0.96
# Epoch [154/200], Step [400/937], d_loss: 0.6742, g_loss:1.44, D(G(z)): 0.60
# Epoch [154/200], Step [600/937], d_loss: 0.1960, g_loss:4.69, D(G(z)): 0.85
# Epoch [154/200], Step [800/937], d_loss: 0.6385, g_loss:4.80, D(G(z)): 0.57
# Epoch [155/200], Step [200/937], d_loss: 0.1410, g_loss:4.20, D(G(z)): 0.94
# Epoch [155/200], Step [400/937], d_loss: 0.2676, g_loss:2.95, D(G(z)): 0.92
# Epoch [155/200], Step [600/937], d_loss: 0.1506, g_loss:1.21, D(G(z)): 0.94
# Epoch [155/200], Step [800/937], d_loss: 0.1298, g_loss:3.35, D(G(z)): 0.98
# Epoch [156/200], Step [200/937], d_loss: 0.0766, g_loss:4.40, D(G(z)): 0.96
# Epoch [156/200], Step [400/937], d_loss: 0.1169, g_loss:4.22, D(G(z)): 0.96
# Epoch [156/200], Step [600/937], d_loss: 0.1352, g_loss:2.84, D(G(z)): 1.00
# Epoch [156/200], Step [800/937], d_loss: 0.6258, g_loss:0.35, D(G(z)): 0.94
# Epoch [157/200], Step [200/937], d_loss: 0.2711, g_loss:4.27, D(G(z)): 0.83
# Epoch [157/200], Step [400/937], d_loss: 0.1929, g_loss:3.10, D(G(z)): 0.88
# Epoch [157/200], Step [600/937], d_loss: 0.6944, g_loss:6.53, D(G(z)): 1.00
# Epoch [157/200], Step [800/937], d_loss: 0.0931, g_loss:3.49, D(G(z)): 0.92
# Epoch [158/200], Step [200/937], d_loss: 0.1366, g_loss:4.52, D(G(z)): 0.99
# Epoch [158/200], Step [400/937], d_loss: 0.7637, g_loss:1.84, D(G(z)): 0.67
# Epoch [158/200], Step [600/937], d_loss: 0.7730, g_loss:3.63, D(G(z)): 0.84
# Epoch [158/200], Step [800/937], d_loss: 0.5992, g_loss:4.51, D(G(z)): 0.85
# Epoch [159/200], Step [200/937], d_loss: 0.1682, g_loss:3.56, D(G(z)): 0.95
# Epoch [159/200], Step [400/937], d_loss: 0.3301, g_loss:5.56, D(G(z)): 0.94
# Epoch [159/200], Step [600/937], d_loss: 0.2184, g_loss:2.49, D(G(z)): 0.93
# Epoch [159/200], Step [800/937], d_loss: 0.0790, g_loss:5.49, D(G(z)): 0.96
# Epoch [160/200], Step [200/937], d_loss: 1.2556, g_loss:6.05, D(G(z)): 0.38
# Epoch [160/200], Step [400/937], d_loss: 0.4059, g_loss:4.51, D(G(z)): 0.74
# Epoch [160/200], Step [600/937], d_loss: 0.3611, g_loss:2.45, D(G(z)): 0.85
# Epoch [160/200], Step [800/937], d_loss: 0.6679, g_loss:3.29, D(G(z)): 0.63
# Epoch [161/200], Step [200/937], d_loss: 0.7591, g_loss:1.80, D(G(z)): 0.94
# Epoch [161/200], Step [400/937], d_loss: 0.1733, g_loss:3.39, D(G(z)): 0.91
# Epoch [161/200], Step [600/937], d_loss: 0.1021, g_loss:1.03, D(G(z)): 0.97
# Epoch [161/200], Step [800/937], d_loss: 0.3681, g_loss:2.24, D(G(z)): 0.94
# Epoch [162/200], Step [200/937], d_loss: 0.1466, g_loss:7.65, D(G(z)): 0.99
# Epoch [162/200], Step [400/937], d_loss: 0.1625, g_loss:2.15, D(G(z)): 0.95
# Epoch [162/200], Step [600/937], d_loss: 0.2200, g_loss:4.75, D(G(z)): 0.95
# Epoch [162/200], Step [800/937], d_loss: 0.0776, g_loss:4.86, D(G(z)): 0.97
# Epoch [163/200], Step [200/937], d_loss: 0.2212, g_loss:2.34, D(G(z)): 0.97
# Epoch [163/200], Step [400/937], d_loss: 0.3081, g_loss:4.74, D(G(z)): 0.84
# Epoch [163/200], Step [600/937], d_loss: 0.1214, g_loss:4.58, D(G(z)): 0.96
# Epoch [163/200], Step [800/937], d_loss: 0.7937, g_loss:4.44, D(G(z)): 0.53
# Epoch [164/200], Step [200/937], d_loss: 0.2349, g_loss:3.83, D(G(z)): 0.82
# Epoch [164/200], Step [400/937], d_loss: 0.3610, g_loss:3.00, D(G(z)): 0.78
# Epoch [164/200], Step [600/937], d_loss: 1.3135, g_loss:4.40, D(G(z)): 0.91
# Epoch [164/200], Step [800/937], d_loss: 1.2875, g_loss:4.18, D(G(z)): 0.97
# Epoch [165/200], Step [200/937], d_loss: 0.1446, g_loss:5.03, D(G(z)): 0.93
# Epoch [165/200], Step [400/937], d_loss: 0.1927, g_loss:1.70, D(G(z)): 0.85
# Epoch [165/200], Step [600/937], d_loss: 0.2511, g_loss:1.50, D(G(z)): 1.00
# Epoch [165/200], Step [800/937], d_loss: 0.1936, g_loss:2.58, D(G(z)): 0.86
# Epoch [166/200], Step [200/937], d_loss: 0.1458, g_loss:6.83, D(G(z)): 0.95
# Epoch [166/200], Step [400/937], d_loss: 0.0800, g_loss:3.99, D(G(z)): 0.97
# Epoch [166/200], Step [600/937], d_loss: 0.3335, g_loss:3.92, D(G(z)): 0.90
# Epoch [166/200], Step [800/937], d_loss: 0.9031, g_loss:5.28, D(G(z)): 0.66
# Epoch [167/200], Step [200/937], d_loss: 0.1699, g_loss:2.87, D(G(z)): 0.90
# Epoch [167/200], Step [400/937], d_loss: 0.2503, g_loss:3.81, D(G(z)): 0.86
# Epoch [167/200], Step [600/937], d_loss: 0.4647, g_loss:4.08, D(G(z)): 0.99
# Epoch [167/200], Step [800/937], d_loss: 0.0212, g_loss:2.86, D(G(z)): 0.99
# Epoch [168/200], Step [200/937], d_loss: 0.9104, g_loss:4.39, D(G(z)): 0.99
# Epoch [168/200], Step [400/937], d_loss: 0.4075, g_loss:4.07, D(G(z)): 0.97
# Epoch [168/200], Step [600/937], d_loss: 0.2543, g_loss:4.28, D(G(z)): 0.99
# Epoch [168/200], Step [800/937], d_loss: 0.8384, g_loss:8.84, D(G(z)): 0.54
# Epoch [169/200], Step [200/937], d_loss: 0.1614, g_loss:3.84, D(G(z)): 0.96
# Epoch [169/200], Step [400/937], d_loss: 0.2562, g_loss:4.05, D(G(z)): 0.81
# Epoch [169/200], Step [600/937], d_loss: 0.0868, g_loss:4.75, D(G(z)): 0.96
# Epoch [169/200], Step [800/937], d_loss: 0.0378, g_loss:4.58, D(G(z)): 0.98
# Epoch [170/200], Step [200/937], d_loss: 0.1982, g_loss:4.32, D(G(z)): 0.87
# Epoch [170/200], Step [400/937], d_loss: 0.2024, g_loss:3.60, D(G(z)): 0.92
# Epoch [170/200], Step [600/937], d_loss: 0.6641, g_loss:1.18, D(G(z)): 0.68
# Epoch [170/200], Step [800/937], d_loss: 0.1435, g_loss:2.09, D(G(z)): 0.99
# Epoch [171/200], Step [200/937], d_loss: 0.0381, g_loss:1.34, D(G(z)): 0.97
# Epoch [171/200], Step [400/937], d_loss: 0.0288, g_loss:3.34, D(G(z)): 0.99
# Epoch [171/200], Step [600/937], d_loss: 0.2263, g_loss:6.19, D(G(z)): 0.91
# Epoch [171/200], Step [800/937], d_loss: 0.0809, g_loss:3.94, D(G(z)): 0.94
# Epoch [172/200], Step [200/937], d_loss: 0.3111, g_loss:4.77, D(G(z)): 0.79
# Epoch [172/200], Step [400/937], d_loss: 0.2158, g_loss:3.13, D(G(z)): 0.98
# Epoch [172/200], Step [600/937], d_loss: 0.2342, g_loss:3.97, D(G(z)): 0.88
# Epoch [172/200], Step [800/937], d_loss: 0.0916, g_loss:6.42, D(G(z)): 0.94
# Epoch [173/200], Step [200/937], d_loss: 0.1729, g_loss:3.76, D(G(z)): 0.98
# Epoch [173/200], Step [400/937], d_loss: 0.3874, g_loss:1.68, D(G(z)): 0.77
# Epoch [173/200], Step [600/937], d_loss: 0.1950, g_loss:1.71, D(G(z)): 0.94
# Epoch [173/200], Step [800/937], d_loss: 0.4038, g_loss:2.49, D(G(z)): 0.83
# Epoch [174/200], Step [200/937], d_loss: 0.4443, g_loss:3.42, D(G(z)): 0.71
# Epoch [174/200], Step [400/937], d_loss: 0.0506, g_loss:4.11, D(G(z)): 1.00
# Epoch [174/200], Step [600/937], d_loss: 0.1836, g_loss:3.76, D(G(z)): 0.92
# Epoch [174/200], Step [800/937], d_loss: 0.9972, g_loss:1.95, D(G(z)): 0.99
# Epoch [175/200], Step [200/937], d_loss: 0.0384, g_loss:2.12, D(G(z)): 0.98
# Epoch [175/200], Step [400/937], d_loss: 0.1563, g_loss:3.28, D(G(z)): 0.96
# Epoch [175/200], Step [600/937], d_loss: 0.0969, g_loss:2.15, D(G(z)): 0.96
# Epoch [175/200], Step [800/937], d_loss: 0.1122, g_loss:5.09, D(G(z)): 0.97
# Epoch [176/200], Step [200/937], d_loss: 0.2416, g_loss:5.56, D(G(z)): 0.99
# Epoch [176/200], Step [400/937], d_loss: 0.1015, g_loss:4.52, D(G(z)): 0.97
# Epoch [176/200], Step [600/937], d_loss: 0.3686, g_loss:3.71, D(G(z)): 0.81
# Epoch [176/200], Step [800/937], d_loss: 0.5010, g_loss:7.37, D(G(z)): 0.70
# Epoch [177/200], Step [200/937], d_loss: 0.1932, g_loss:3.17, D(G(z)): 0.85
# Epoch [177/200], Step [400/937], d_loss: 0.3021, g_loss:1.89, D(G(z)): 0.97
# Epoch [177/200], Step [600/937], d_loss: 0.1588, g_loss:3.25, D(G(z)): 0.89
# Epoch [177/200], Step [800/937], d_loss: 0.9999, g_loss:5.75, D(G(z)): 0.79
# Epoch [178/200], Step [200/937], d_loss: 0.2182, g_loss:4.67, D(G(z)): 0.88
# Epoch [178/200], Step [400/937], d_loss: 0.1797, g_loss:3.62, D(G(z)): 0.89
# Epoch [178/200], Step [600/937], d_loss: 0.0545, g_loss:5.54, D(G(z)): 0.97
# Epoch [178/200], Step [800/937], d_loss: 1.8643, g_loss:3.24, D(G(z)): 1.00
# Epoch [179/200], Step [200/937], d_loss: 0.0403, g_loss:2.77, D(G(z)): 0.99
# Epoch [179/200], Step [400/937], d_loss: 0.1518, g_loss:2.63, D(G(z)): 0.95
# Epoch [179/200], Step [600/937], d_loss: 0.2430, g_loss:2.59, D(G(z)): 0.89
# Epoch [179/200], Step [800/937], d_loss: 0.2805, g_loss:5.49, D(G(z)): 0.93
# Epoch [180/200], Step [200/937], d_loss: 0.2148, g_loss:1.46, D(G(z)): 0.91
# Epoch [180/200], Step [400/937], d_loss: 0.1504, g_loss:5.14, D(G(z)): 0.91
# Epoch [180/200], Step [600/937], d_loss: 0.2885, g_loss:4.93, D(G(z)): 0.92
# Epoch [180/200], Step [800/937], d_loss: 0.3100, g_loss:3.71, D(G(z)): 0.76
# Epoch [181/200], Step [200/937], d_loss: 0.0781, g_loss:4.40, D(G(z)): 0.97
# Epoch [181/200], Step [400/937], d_loss: 0.2653, g_loss:3.07, D(G(z)): 0.85
# Epoch [181/200], Step [600/937], d_loss: 0.2054, g_loss:2.90, D(G(z)): 0.93
# Epoch [181/200], Step [800/937], d_loss: 0.1931, g_loss:3.16, D(G(z)): 0.84
# Epoch [182/200], Step [200/937], d_loss: 0.1055, g_loss:5.14, D(G(z)): 1.00
# Epoch [182/200], Step [400/937], d_loss: 0.3348, g_loss:3.25, D(G(z)): 0.77
# Epoch [182/200], Step [600/937], d_loss: 0.1981, g_loss:4.11, D(G(z)): 0.96
# Epoch [182/200], Step [800/937], d_loss: 0.4727, g_loss:2.97, D(G(z)): 0.71
# Epoch [183/200], Step [200/937], d_loss: 0.2350, g_loss:3.84, D(G(z)): 0.86
# Epoch [183/200], Step [400/937], d_loss: 0.3817, g_loss:3.35, D(G(z)): 0.78
# Epoch [183/200], Step [600/937], d_loss: 0.4012, g_loss:2.35, D(G(z)): 0.82
# Epoch [183/200], Step [800/937], d_loss: 0.9817, g_loss:5.08, D(G(z)): 0.96
# Epoch [184/200], Step [200/937], d_loss: 1.1165, g_loss:4.15, D(G(z)): 0.97
# Epoch [184/200], Step [400/937], d_loss: 0.1338, g_loss:5.41, D(G(z)): 0.97
# Epoch [184/200], Step [600/937], d_loss: 0.4372, g_loss:3.92, D(G(z)): 0.89
# Epoch [184/200], Step [800/937], d_loss: 0.1744, g_loss:6.13, D(G(z)): 0.88
# Epoch [185/200], Step [200/937], d_loss: 0.0961, g_loss:2.68, D(G(z)): 0.93
# Epoch [185/200], Step [400/937], d_loss: 0.2110, g_loss:3.52, D(G(z)): 0.98
# Epoch [185/200], Step [600/937], d_loss: 0.0446, g_loss:1.29, D(G(z)): 0.96
# Epoch [185/200], Step [800/937], d_loss: 0.1394, g_loss:3.80, D(G(z)): 0.95
# Epoch [186/200], Step [200/937], d_loss: 0.7613, g_loss:2.47, D(G(z)): 0.98
# Epoch [186/200], Step [400/937], d_loss: 0.2626, g_loss:4.53, D(G(z)): 0.93
# Epoch [186/200], Step [600/937], d_loss: 1.2659, g_loss:1.58, D(G(z)): 0.72
# Epoch [186/200], Step [800/937], d_loss: 0.4012, g_loss:2.71, D(G(z)): 0.76
# Epoch [187/200], Step [200/937], d_loss: 1.7748, g_loss:5.27, D(G(z)): 0.99
# Epoch [187/200], Step [400/937], d_loss: 0.0613, g_loss:4.99, D(G(z)): 0.99
# Epoch [187/200], Step [600/937], d_loss: 0.1941, g_loss:4.73, D(G(z)): 0.98
# Epoch [187/200], Step [800/937], d_loss: 0.1232, g_loss:0.77, D(G(z)): 0.94
# Epoch [188/200], Step [200/937], d_loss: 0.6642, g_loss:3.94, D(G(z)): 0.97
# Epoch [188/200], Step [400/937], d_loss: 0.3490, g_loss:2.66, D(G(z)): 0.98
# Epoch [188/200], Step [600/937], d_loss: 0.5134, g_loss:6.97, D(G(z)): 0.67
# Epoch [188/200], Step [800/937], d_loss: 0.1181, g_loss:3.46, D(G(z)): 1.00
# Epoch [189/200], Step [200/937], d_loss: 0.2432, g_loss:5.96, D(G(z)): 0.97
# Epoch [189/200], Step [400/937], d_loss: 0.0776, g_loss:5.21, D(G(z)): 0.93
# Epoch [189/200], Step [600/937], d_loss: 0.3242, g_loss:4.06, D(G(z)): 0.77
# Epoch [189/200], Step [800/937], d_loss: 0.5897, g_loss:2.50, D(G(z)): 0.78
# Epoch [190/200], Step [200/937], d_loss: 0.6426, g_loss:4.07, D(G(z)): 0.58
# Epoch [190/200], Step [400/937], d_loss: 0.0602, g_loss:3.74, D(G(z)): 0.95
# Epoch [190/200], Step [600/937], d_loss: 0.2136, g_loss:2.64, D(G(z)): 1.00
# Epoch [190/200], Step [800/937], d_loss: 0.0713, g_loss:1.57, D(G(z)): 0.96
# Epoch [191/200], Step [200/937], d_loss: 5.4366, g_loss:6.02, D(G(z)): 0.01
# Epoch [191/200], Step [400/937], d_loss: 0.2487, g_loss:4.40, D(G(z)): 0.82
# Epoch [191/200], Step [600/937], d_loss: 0.7838, g_loss:1.83, D(G(z)): 0.55
# Epoch [191/200], Step [800/937], d_loss: 0.3976, g_loss:1.47, D(G(z)): 0.72
# Epoch [192/200], Step [200/937], d_loss: 0.2986, g_loss:4.00, D(G(z)): 0.98
# Epoch [192/200], Step [400/937], d_loss: 0.7279, g_loss:4.50, D(G(z)): 0.72
# Epoch [192/200], Step [600/937], d_loss: 0.1717, g_loss:1.84, D(G(z)): 0.97
# Epoch [192/200], Step [800/937], d_loss: 0.3222, g_loss:6.38, D(G(z)): 0.88
# Epoch [193/200], Step [200/937], d_loss: 0.2626, g_loss:7.28, D(G(z)): 0.80
# Epoch [193/200], Step [400/937], d_loss: 0.1668, g_loss:4.97, D(G(z)): 0.88
# Epoch [193/200], Step [600/937], d_loss: 0.0824, g_loss:2.21, D(G(z)): 0.95
# Epoch [193/200], Step [800/937], d_loss: 0.3519, g_loss:3.35, D(G(z)): 1.00
# Epoch [194/200], Step [200/937], d_loss: 0.5059, g_loss:5.42, D(G(z)): 0.71
# Epoch [194/200], Step [400/937], d_loss: 0.1427, g_loss:2.43, D(G(z)): 0.93
# Epoch [194/200], Step [600/937], d_loss: 0.2896, g_loss:4.06, D(G(z)): 0.87
# Epoch [194/200], Step [800/937], d_loss: 0.4079, g_loss:6.05, D(G(z)): 0.77
# Epoch [195/200], Step [200/937], d_loss: 0.1451, g_loss:4.23, D(G(z)): 0.95
# Epoch [195/200], Step [400/937], d_loss: 0.1996, g_loss:5.75, D(G(z)): 0.87
# Epoch [195/200], Step [600/937], d_loss: 0.2943, g_loss:4.10, D(G(z)): 0.96
# Epoch [195/200], Step [800/937], d_loss: 0.3455, g_loss:2.73, D(G(z)): 0.74
# Epoch [196/200], Step [200/937], d_loss: 0.1966, g_loss:2.36, D(G(z)): 0.93
# Epoch [196/200], Step [400/937], d_loss: 0.0468, g_loss:6.18, D(G(z)): 0.97
# Epoch [196/200], Step [600/937], d_loss: 0.3398, g_loss:3.26, D(G(z)): 0.80
# Epoch [196/200], Step [800/937], d_loss: 0.0562, g_loss:2.53, D(G(z)): 0.98
# Epoch [197/200], Step [200/937], d_loss: 0.2304, g_loss:3.04, D(G(z)): 0.96
# Epoch [197/200], Step [400/937], d_loss: 0.1607, g_loss:1.18, D(G(z)): 0.99
# Epoch [197/200], Step [600/937], d_loss: 0.2043, g_loss:4.81, D(G(z)): 0.85
# Epoch [197/200], Step [800/937], d_loss: 0.2754, g_loss:3.31, D(G(z)): 0.85
# Epoch [198/200], Step [200/937], d_loss: 0.0317, g_loss:4.03, D(G(z)): 0.98
# Epoch [198/200], Step [400/937], d_loss: 0.2571, g_loss:2.99, D(G(z)): 0.84
# Epoch [198/200], Step [600/937], d_loss: 0.1781, g_loss:5.92, D(G(z)): 0.87
# Epoch [198/200], Step [800/937], d_loss: 0.4609, g_loss:2.92, D(G(z)): 0.70
# Epoch [199/200], Step [200/937], d_loss: 0.1054, g_loss:3.27, D(G(z)): 0.98
# Epoch [199/200], Step [400/937], d_loss: 0.2216, g_loss:3.29, D(G(z)): 0.98
# Epoch [199/200], Step [600/937], d_loss: 0.1304, g_loss:4.96, D(G(z)): 0.90
# Epoch [199/200], Step [800/937], d_loss: 0.0910, g_loss:2.66, D(G(z)): 0.97

# %%
torch.randint(10,[3,2])
